# %% [markdown]
# Imports

# %%
import cv2
import matplotlib.pyplot as plt 
import pandas as pd
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from os import listdir

# %% [markdown]
# Reading data

# %%
folder_dir = "/home/davide/Documents/Deepfake-Classification/deepfake-classification"
img_dir = "/home/davide/Documents/Deepfake-Classification/deepfake-classification/train"

test_dir = "/home/davide/Documents/Deepfake-Classification/deepfake-classification/test"
test_file = os.path.join(folder_dir, "test.csv")  

csv_file = os.path.join(folder_dir, "train.csv")

validation_file = os.path.join(folder_dir, "validation.csv")
val_dir = "/home/davide/Documents/Deepfake-Classification/deepfake-classification/validation"

# %% [markdown]
# Training

# %%
class NeuralNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1_1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1, bias=False)
        self.bn1_1 = nn.BatchNorm2d(32)
        self.conv1_2 = nn.Conv2d(32, 32, kernel_size=3, padding=1, bias=False)
        self.bn1_2 = nn.BatchNorm2d(32)

        self.conv2_1 = nn.Conv2d(32, 64, kernel_size=3, padding=1, bias=False)
        self.bn2_1 = nn.BatchNorm2d(64)
        self.conv2_2 = nn.Conv2d(64, 64, kernel_size=3, padding=1, bias=False)
        self.bn2_2 = nn.BatchNorm2d(64)

        self.conv3_1 = nn.Conv2d(64, 128, kernel_size=3, padding=1, bias=False)
        self.bn3_1 = nn.BatchNorm2d(128)
        self.conv3_2 = nn.Conv2d(128, 128, kernel_size=3, padding=1, bias=False)
        self.bn3_2 = nn.BatchNorm2d(128)
        self.conv3_3 = nn.Conv2d(128, 128, kernel_size=3, padding=1, bias=False)
        self.bn3_3 = nn.BatchNorm2d(128)

        self.conv4_1 = nn.Conv2d(128, 256, kernel_size=3, padding=1, bias=False)
        self.bn4_1 = nn.BatchNorm2d(256)
        self.conv4_2 = nn.Conv2d(256, 256, kernel_size=3, padding=1, bias=False)
        self.bn4_2 = nn.BatchNorm2d(256)
        self.conv4_3 = nn.Conv2d(256, 256, kernel_size=3, padding=1, bias=False)
        self.bn4_3 = nn.BatchNorm2d(256)

        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(0.5)

        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Linear(256, 10)

    def forward(self, x):
        
        x = F.relu(self.bn1_1(self.conv1_1(x)))
        x = F.relu(self.bn1_2(self.conv1_2(x)))
        x = self.pool(x)

        x = F.relu(self.bn2_1(self.conv2_1(x)))
        x = F.relu(self.bn2_2(self.conv2_2(x)))
        x = self.pool(x)

        x = F.relu(self.bn3_1(self.conv3_1(x)))
        x = F.relu(self.bn3_2(self.conv3_2(x)))
        x = F.relu(self.bn3_3(self.conv3_3(x)))
        x = self.pool(x)

        x = F.relu(self.bn4_1(self.conv4_1(x)))
        x = F.relu(self.bn4_2(self.conv4_2(x)))
        x = F.relu(self.bn4_3(self.conv4_3(x)))
        x = self.pool(x)

        x = self.global_avg_pool(x) 
        x = torch.flatten(x, 1)      
        x = self.dropout(x)
        x = self.fc(x)
        return x

    
model = NeuralNet()

df_train = pd.read_csv(csv_file)

data = []
for idx, row in df_train.iterrows():
    img_name = row['image_id'] + '.png'
    label = row['label']
    img_path = os.path.join(img_dir, img_name)
    image = cv2.imread(img_path)

    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # height, width, channels = image_rgb.shape

    # print(f"Original image width: {width} pixels")   100
    # print(f"Original image height: {height} pixels") 100
    # print(f"Number of channels: {channels}")         3
    image_resized = cv2.resize(image_rgb, (100, 100))
    normalized_image = cv2.normalize(image_resized.astype('float32'), None, 0, 1, cv2.NORM_MINMAX)

    image_tensor = torch.from_numpy(normalized_image).permute(2, 0, 1).float()

    data.append((image_tensor, label))

images = torch.stack([item[0] for item in data])
labels = torch.tensor([item[1] for item in data])

dataset = TensorDataset(images, labels)
train_loader = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=8)

# optimizer = torch.optim.Adam(model.parameters(), lr=0.006, weight_decay=1e-5)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5)

# residual blocks and skip connection 

optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.82, weight_decay=1e-4, nesterov=True)
scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer, base_lr=0.001, max_lr=0.01, step_size_up=2000)


NUM_EPOCHS = 130
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")
model = model.to(device) 
loss_function = nn.CrossEntropyLoss() 

train_losses = []
train_accuracies = []

model.train(True)
for epoch in range(NUM_EPOCHS): 
    print(f"=== Epoch {epoch+1} ===")
    ####################
    running_loss = 0.0
    correct = 0
    total = 0
    ###################
    for i, (inputs, labels) in enumerate(train_loader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad(set_to_none=True)
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        scheduler.step()

#####################################################
        running_loss += loss.item() * inputs.size(0)
        predicted = outputs.argmax(dim=1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)
#####################################################

        if i % 100 == 0:
            print(f"Batch {i}, Loss: {loss.item():.4f}")

##################################################################################
    epoch_loss = running_loss / total
    epoch_acc = correct / total
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_acc)
    # scheduler.step(epoch_loss)
    print(f"Epoch {epoch+1} Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}")
    if epoch_acc > 0.995:
        print(f"Stopping early at epoch {epoch+1} as accuracy is {epoch_acc: .4f}")
        break
##################################################################################
print('Finished Training')
epochs = range(1, len(train_losses) + 1)
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_losses, 'b-', label='Training Loss')
plt.plot(epochs, train_accuracies, 'r-', label='Training Accuracy')
plt.xlabel('Epoch')
plt.title('Training Loss and Accuracy')
plt.legend()
plt.show()
# Out:
# Device: cuda
# === Epoch 1 ===
# Batch 0, Loss: 2.6490
# Batch 100, Loss: 0.7510
# Batch 200, Loss: 0.5456
# Batch 300, Loss: 0.7000
# Epoch 1 Loss: 0.8455, Accuracy: 0.6730
# === Epoch 2 ===
# Batch 0, Loss: 0.6143
# Batch 100, Loss: 0.5938
# Batch 200, Loss: 1.1882
# Batch 300, Loss: 0.4312
# Epoch 2 Loss: 0.6080, Accuracy: 0.7690
# === Epoch 3 ===
# Batch 0, Loss: 1.0090
# Batch 100, Loss: 0.3151
# Batch 200, Loss: 0.8326
# Batch 300, Loss: 0.6729
# Epoch 3 Loss: 0.5385, Accuracy: 0.7940
# === Epoch 4 ===
# Batch 0, Loss: 0.5241
# Batch 100, Loss: 0.5397
# Batch 200, Loss: 0.5069
# Batch 300, Loss: 0.4118
# Epoch 4 Loss: 0.4993, Accuracy: 0.8116
# === Epoch 5 ===
# Batch 0, Loss: 0.3451
# Batch 100, Loss: 0.4482
# Batch 200, Loss: 0.5152
# Batch 300, Loss: 0.2926
# Epoch 5 Loss: 0.4562, Accuracy: 0.8326
# === Epoch 6 ===
# Batch 0, Loss: 0.4651
# Batch 100, Loss: 0.2515
# Batch 200, Loss: 0.1364
# Batch 300, Loss: 0.6735
# Epoch 6 Loss: 0.4184, Accuracy: 0.8415
# === Epoch 7 ===
# Batch 0, Loss: 0.3109
# Batch 100, Loss: 0.2459
# Batch 200, Loss: 0.4130
# Batch 300, Loss: 0.1518
# Epoch 7 Loss: 0.3680, Accuracy: 0.8623
# === Epoch 8 ===
# Batch 0, Loss: 0.3455
# Batch 100, Loss: 0.3923
# Batch 200, Loss: 0.3048
# Batch 300, Loss: 0.2199
# Epoch 8 Loss: 0.3109, Accuracy: 0.8843
# === Epoch 9 ===
# Batch 0, Loss: 0.5138
# Batch 100, Loss: 0.1414
# Batch 200, Loss: 0.4333
# Batch 300, Loss: 0.2175
# Epoch 9 Loss: 0.2867, Accuracy: 0.8930
# === Epoch 10 ===
# Batch 0, Loss: 0.1637
# Batch 100, Loss: 0.2826
# Batch 200, Loss: 0.2179
# Batch 300, Loss: 0.1038
# Epoch 10 Loss: 0.2318, Accuracy: 0.9128
# === Epoch 11 ===
# Batch 0, Loss: 0.0302
# Batch 100, Loss: 0.1060
# Batch 200, Loss: 0.1532
# Batch 300, Loss: 0.1729
# Epoch 11 Loss: 0.1930, Accuracy: 0.9301
# === Epoch 12 ===
# Batch 0, Loss: 0.3907
# Batch 100, Loss: 0.1389
# Batch 200, Loss: 0.2091
# Batch 300, Loss: 0.0472
# Epoch 12 Loss: 0.2246, Accuracy: 0.9156
# === Epoch 13 ===
# Batch 0, Loss: 0.1975
# Batch 100, Loss: 0.2978
# Batch 200, Loss: 0.3909
# Batch 300, Loss: 0.2034
# Epoch 13 Loss: 0.2484, Accuracy: 0.9089
# === Epoch 14 ===
# Batch 0, Loss: 0.3946
# Batch 100, Loss: 0.3356
# Batch 200, Loss: 0.1434
# Batch 300, Loss: 0.2772
# Epoch 14 Loss: 0.2668, Accuracy: 0.9013
# === Epoch 15 ===
# Batch 0, Loss: 0.1629
# Batch 100, Loss: 0.3682
# Batch 200, Loss: 0.2479
# Batch 300, Loss: 0.2017
# Epoch 15 Loss: 0.2524, Accuracy: 0.9074
# === Epoch 16 ===
# Batch 0, Loss: 0.4788
# Batch 100, Loss: 0.2675
# Batch 200, Loss: 0.1416
# Batch 300, Loss: 0.1233
# Epoch 16 Loss: 0.2590, Accuracy: 0.9029
# === Epoch 17 ===
# Batch 0, Loss: 0.0461
# Batch 100, Loss: 0.1561
# Batch 200, Loss: 0.3592
# Batch 300, Loss: 0.3389
# Epoch 17 Loss: 0.2114, Accuracy: 0.9233
# === Epoch 18 ===
# Batch 0, Loss: 0.3401
# Batch 100, Loss: 0.1291
# Batch 200, Loss: 0.5455
# Batch 300, Loss: 0.1154
# Epoch 18 Loss: 0.1812, Accuracy: 0.9335
# === Epoch 19 ===
# Batch 0, Loss: 0.2705
# Batch 100, Loss: 0.0249
# Batch 200, Loss: 0.2487
# Batch 300, Loss: 0.0998
# Epoch 19 Loss: 0.1475, Accuracy: 0.9464
# === Epoch 20 ===
# Batch 0, Loss: 0.0803
# Batch 100, Loss: 0.1579
# Batch 200, Loss: 0.0844
# Batch 300, Loss: 0.0418
# Epoch 20 Loss: 0.1099, Accuracy: 0.9599
# === Epoch 21 ===
# Batch 0, Loss: 0.0861
# Batch 100, Loss: 0.0538
# Batch 200, Loss: 0.0494
# Batch 300, Loss: 0.0246
# Epoch 21 Loss: 0.0655, Accuracy: 0.9794
# === Epoch 22 ===
# Batch 0, Loss: 0.0940
# Batch 100, Loss: 0.0281
# Batch 200, Loss: 0.2851
# Batch 300, Loss: 0.1043
# Epoch 22 Loss: 0.0867, Accuracy: 0.9698
# === Epoch 23 ===
# Batch 0, Loss: 0.0274
# Batch 100, Loss: 0.0208
# Batch 200, Loss: 0.0395
# Batch 300, Loss: 0.3065
# Epoch 23 Loss: 0.1376, Accuracy: 0.9514
# === Epoch 24 ===
# Batch 0, Loss: 0.0719
# Batch 100, Loss: 0.0545
# Batch 200, Loss: 0.1867
# Batch 300, Loss: 0.1591
# Epoch 24 Loss: 0.1479, Accuracy: 0.9450
# === Epoch 25 ===
# Batch 0, Loss: 0.0517
# Batch 100, Loss: 0.1661
# Batch 200, Loss: 0.0356
# Batch 300, Loss: 0.5781
# Epoch 25 Loss: 0.1651, Accuracy: 0.9404
# === Epoch 26 ===
# Batch 0, Loss: 0.1748
# Batch 100, Loss: 0.0877
# Batch 200, Loss: 0.2177
# Batch 300, Loss: 0.1814
# Epoch 26 Loss: 0.1675, Accuracy: 0.9383
# === Epoch 27 ===
# Batch 0, Loss: 0.2046
# Batch 100, Loss: 0.2056
# Batch 200, Loss: 0.0317
# Batch 300, Loss: 0.1545
# Epoch 27 Loss: 0.1365, Accuracy: 0.9496
# === Epoch 28 ===
# Batch 0, Loss: 0.0335
# Batch 100, Loss: 0.0687
# Batch 200, Loss: 0.0671
# Batch 300, Loss: 0.1341
# Epoch 28 Loss: 0.1020, Accuracy: 0.9627
# === Epoch 29 ===
# Batch 0, Loss: 0.1646
# Batch 100, Loss: 0.0295
# Batch 200, Loss: 0.1112
# Batch 300, Loss: 0.0168
# Epoch 29 Loss: 0.0723, Accuracy: 0.9753
# === Epoch 30 ===
# Batch 0, Loss: 0.0079
# Batch 100, Loss: 0.0062
# Batch 200, Loss: 0.0610
# Batch 300, Loss: 0.0525
# Epoch 30 Loss: 0.0412, Accuracy: 0.9886
# === Epoch 31 ===
# Batch 0, Loss: 0.0087
# Batch 100, Loss: 0.0122
# Batch 200, Loss: 0.0050
# Batch 300, Loss: 0.0281
# Epoch 31 Loss: 0.0254, Accuracy: 0.9934
# === Epoch 32 ===
# Batch 0, Loss: 0.0023
# Batch 100, Loss: 0.0205
# Batch 200, Loss: 0.0116
# Batch 300, Loss: 0.0634
# Epoch 32 Loss: 0.0240, Accuracy: 0.9935
# === Epoch 33 ===
# Batch 0, Loss: 0.0124
# Batch 100, Loss: 0.0217
# Batch 200, Loss: 0.1999
# Batch 300, Loss: 0.0984
# Epoch 33 Loss: 0.0447, Accuracy: 0.9858
# === Epoch 34 ===
# Batch 0, Loss: 0.1078
# Batch 100, Loss: 0.0899
# Batch 200, Loss: 0.1663
# Batch 300, Loss: 0.1322
# Epoch 34 Loss: 0.0756, Accuracy: 0.9746
# === Epoch 35 ===
# Batch 0, Loss: 0.1470
# Batch 100, Loss: 0.2261
# Batch 200, Loss: 0.0237
# Batch 300, Loss: 0.2253
# Epoch 35 Loss: 0.0950, Accuracy: 0.9650
# === Epoch 36 ===
# Batch 0, Loss: 0.0594
# Batch 100, Loss: 0.0880
# Batch 200, Loss: 0.2219
# Batch 300, Loss: 0.0347
# Epoch 36 Loss: 0.1220, Accuracy: 0.9574
# === Epoch 37 ===
# Batch 0, Loss: 0.0899
# Batch 100, Loss: 0.0796
# Batch 200, Loss: 0.0544
# Batch 300, Loss: 0.0619
# Epoch 37 Loss: 0.0841, Accuracy: 0.9697
# === Epoch 38 ===
# Batch 0, Loss: 0.0543
# Batch 100, Loss: 0.0206
# Batch 200, Loss: 0.1030
# Batch 300, Loss: 0.0459
# Epoch 38 Loss: 0.0610, Accuracy: 0.9787
# === Epoch 39 ===
# Batch 0, Loss: 0.0596
# Batch 100, Loss: 0.0130
# Batch 200, Loss: 0.0060
# Batch 300, Loss: 0.0224
# Epoch 39 Loss: 0.0345, Accuracy: 0.9881
# === Epoch 40 ===
# Batch 0, Loss: 0.0062
# Batch 100, Loss: 0.0017
# Batch 200, Loss: 0.0115
# Batch 300, Loss: 0.0556
# Epoch 40 Loss: 0.0263, Accuracy: 0.9916
# === Epoch 41 ===
# Batch 0, Loss: 0.0101
# Batch 100, Loss: 0.0050
# Batch 200, Loss: 0.0270
# Batch 300, Loss: 0.0056
# Epoch 41 Loss: 0.0151, Accuracy: 0.9956
# Stopping early at epoch 41 as accuracy is  0.9956
# Finished Training

# %% [markdown]
# Test

# %%
df_test = pd.read_csv(test_file)

test_data = []
image_ids = []
for idx, row in df_test.iterrows():
    img_name = row['image_id'] + '.png'
    img_path = os.path.join(test_dir, img_name)
    image = cv2.imread(img_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_resized = cv2.resize(image_rgb, (100, 100))
    
    normalized_image = cv2.normalize(image_resized.astype('float32'), None, 0, 1, cv2.NORM_MINMAX)
    image_tensor = torch.from_numpy(normalized_image).permute(2, 0, 1).float()
    test_data.append(image_tensor)
    image_ids.append(row['image_id'])

test_images = torch.stack(test_data)
test_dataset = TensorDataset(test_images) 
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=8)

model.to(device)
model.eval()
predicted_labels = []
with torch.no_grad():
    for image_batch in test_loader:
        images = image_batch[0].to(device)
        outputs = model(images)
        preds = outputs.argmax(dim=1).cpu()
        predicted_labels.extend(preds.tolist())

print(predicted_labels)
predictions_df = pd.DataFrame({'image_id': image_ids, 'label': predicted_labels})
predictions_df.to_csv('deepfake-classification/cnn_prediction.csv', index=False)
print("Predictions saved to prediction.csv")
# Out:
# [4, 3, 0, 2, 1, 3, 0, 1, 3, 1, 3, 2, 3, 2, 2, 1, 0, 3, 3, 3, 4, 0, 0, 0, 1, 3, 1, 2, 4, 3, 3, 4, 2, 1, 2, 0, 4, 1, 3, 1, 0, 0, 0, 2, 0, 2, 1, 2, 4, 3, 4, 1, 3, 1, 3, 3, 2, 1, 2, 4, 1, 2, 2, 0, 4, 2, 1, 4, 2, 1, 3, 1, 0, 0, 1, 2, 3, 2, 2, 3, 1, 1, 2, 0, 3, 1, 4, 0, 2, 0, 0, 1, 3, 1, 1, 4, 0, 3, 2, 4, 3, 3, 3, 2, 2, 2, 3, 4, 2, 4, 4, 0, 3, 1, 2, 2, 1, 3, 4, 1, 3, 1, 4, 1, 0, 4, 3, 4, 2, 4, 1, 3, 1, 3, 4, 2, 0, 1, 1, 2, 3, 1, 4, 3, 3, 4, 3, 3, 0, 3, 2, 0, 1, 2, 2, 1, 3, 1, 0, 4, 0, 0, 2, 4, 0, 2, 2, 2, 2, 1, 3, 1, 0, 4, 0, 4, 4, 4, 1, 0, 1, 3, 2, 1, 2, 4, 4, 3, 3, 4, 2, 2, 3, 1, 4, 3, 2, 0, 0, 2, 2, 1, 2, 2, 4, 0, 3, 0, 3, 1, 0, 0, 0, 0, 2, 4, 4, 1, 1, 4, 0, 1, 3, 1, 0, 2, 4, 4, 1, 0, 2, 4, 3, 4, 4, 0, 3, 2, 2, 1, 0, 2, 0, 1, 0, 3, 4, 0, 3, 1, 4, 3, 3, 1, 3, 1, 3, 0, 2, 2, 1, 2, 4, 1, 0, 1, 4, 0, 4, 0, 4, 4, 1, 0, 4, 0, 3, 2, 2, 2, 4, 4, 3, 0, 0, 0, 3, 1, 0, 2, 0, 4, 1, 2, 3, 1, 1, 4, 3, 3, 3, 3, 1, 1, 0, 3, 4, 0, 4, 4, 3, 1, 3, 1, 3, 3, 0, 4, 1, 2, 1, 4, 0, 4, 0, 4, 2, 0, 0, 2, 0, 0, 1, 2, 0, 3, 1, 0, 0, 0, 1, 0, 1, 3, 2, 1, 0, 1, 4, 0, 3, 3, 2, 3, 2, 2, 0, 2, 4, 0, 2, 2, 3, 2, 2, 1, 0, 4, 2, 0, 1, 4, 0, 1, 1, 1, 1, 1, 3, 0, 4, 2, 1, 3, 0, 1, 0, 3, 4, 4, 0, 4, 3, 3, 2, 0, 2, 2, 1, 4, 2, 1, 0, 0, 3, 4, 2, 3, 0, 3, 1, 2, 0, 2, 1, 3, 3, 3, 3, 2, 3, 4, 3, 0, 0, 0, 0, 1, 0, 3, 1, 4, 4, 0, 2, 0, 3, 1, 1, 1, 2, 2, 2, 0, 2, 4, 1, 2, 2, 1, 3, 4, 3, 4, 2, 0, 0, 4, 0, 4, 1, 1, 1, 1, 3, 0, 2, 0, 4, 4, 2, 3, 4, 2, 4, 2, 4, 4, 0, 3, 2, 4, 4, 4, 0, 4, 0, 1, 0, 3, 3, 0, 2, 2, 1, 3, 3, 2, 4, 0, 4, 4, 1, 3, 1, 3, 0, 2, 1, 4, 0, 1, 4, 3, 4, 3, 1, 0, 2, 2, 1, 1, 3, 3, 2, 0, 0, 2, 3, 4, 3, 1, 3, 0, 4, 2, 2, 2, 0, 2, 0, 3, 0, 3, 0, 4, 0, 0, 2, 3, 2, 2, 3, 1, 2, 0, 1, 0, 3, 1, 2, 1, 4, 1, 2, 3, 3, 1, 0, 1, 0, 0, 4, 3, 2, 2, 4, 4, 4, 1, 0, 0, 2, 4, 2, 1, 1, 1, 4, 2, 3, 2, 1, 2, 0, 1, 1, 1, 1, 0, 2, 0, 0, 4, 1, 3, 3, 0, 1, 1, 0, 3, 2, 2, 2, 3, 4, 4, 1, 3, 0, 2, 2, 3, 3, 1, 4, 3, 1, 1, 2, 0, 2, 1, 2, 2, 0, 4, 4, 3, 1, 2, 4, 0, 3, 0, 2, 4, 4, 2, 1, 0, 3, 3, 3, 3, 3, 4, 0, 3, 4, 4, 4, 4, 0, 3, 4, 4, 3, 2, 3, 2, 2, 4, 4, 0, 3, 1, 2, 2, 0, 1, 0, 4, 4, 0, 4, 3, 4, 3, 4, 2, 0, 0, 2, 1, 2, 4, 2, 3, 3, 1, 1, 1, 4, 0, 4, 3, 1, 0, 2, 1, 1, 4, 2, 2, 1, 1, 2, 2, 3, 4, 3, 0, 0, 3, 4, 0, 3, 2, 1, 3, 0, 1, 1, 1, 4, 0, 3, 1, 1, 2, 4, 2, 3, 2, 1, 0, 3, 3, 1, 3, 4, 4, 1, 2, 1, 0, 1, 3, 1, 0, 1, 1, 3, 3, 2, 2, 1, 4, 2, 0, 3, 4, 0, 0, 2, 1, 3, 0, 2, 3, 2, 3, 2, 1, 0, 3, 2, 4, 2, 0, 3, 4, 3, 0, 3, 1, 2, 4, 4, 0, 0, 2, 2, 1, 2, 0, 2, 4, 2, 2, 3, 1, 4, 4, 2, 0, 0, 0, 2, 2, 4, 1, 2, 2, 4, 3, 1, 0, 3, 3, 2, 0, 0, 4, 3, 2, 0, 0, 1, 1, 2, 3, 3, 4, 4, 2, 0, 2, 2, 2, 1, 2, 3, 0, 1, 3, 0, 2, 1, 0, 4, 1, 0, 1, 3, 0, 3, 3, 1, 1, 3, 0, 2, 4, 4, 1, 3, 0, 4, 1, 1, 2, 4, 3, 2, 4, 2, 2, 4, 4, 3, 1, 4, 1, 1, 1, 0, 2, 0, 0, 2, 4, 0, 0, 3, 1, 0, 4, 4, 4, 3, 3, 3, 1, 2, 4, 0, 2, 4, 3, 3, 2, 0, 0, 0, 0, 1, 4, 0, 3, 3, 3, 0, 1, 2, 2, 1, 1, 1, 2, 3, 2, 3, 1, 0, 3, 0, 2, 0, 1, 1, 4, 0, 2, 0, 3, 3, 1, 2, 2, 1, 0, 1, 4, 4, 2, 1, 3, 4, 3, 3, 3, 2, 1, 3, 1, 1, 1, 3, 3, 4, 3, 4, 2, 2, 0, 1, 4, 1, 1, 1, 1, 3, 0, 3, 0, 0, 0, 1, 4, 4, 1, 0, 1, 0, 2, 3, 1, 4, 2, 1, 1, 4, 2, 0, 2, 3, 3, 2, 0, 2, 1, 0, 1, 4, 0, 4, 2, 2, 1, 3, 2, 3, 1, 4, 0, 3, 3, 3, 2, 1, 3, 2, 0, 1, 0, 4, 0, 0, 2, 4, 1, 1, 0, 1, 1, 2, 4, 2, 4, 2, 3, 3, 2, 1, 1, 3, 4, 4, 4, 4, 3, 1, 0, 4, 1, 0, 0, 2, 2, 3, 1, 0, 0, 1, 2, 2, 1, 0, 1, 0, 3, 2, 0, 3, 2, 3, 2, 2, 4, 0, 0, 0, 4, 0, 0, 2, 4, 0, 1, 4, 4, 2, 4, 3, 2, 0, 4, 1, 1, 3, 2, 3, 2, 4, 3, 3, 0, 4, 2, 2, 0, 3, 3, 0, 4, 3, 3, 3, 0, 0, 3, 0, 1, 0, 4, 4, 4, 3, 4, 0, 3, 4, 3, 4, 3, 0, 0, 1, 4, 1, 3, 1, 4, 4, 0, 2, 1, 2, 1, 3, 2, 3, 2, 0, 4, 4, 3, 3, 2, 3, 1, 4, 3, 4, 2, 0, 4, 2, 1, 4, 4, 1, 3, 1, 0, 0, 0, 0, 0, 3, 1, 2, 2, 1, 0, 4, 0, 4, 4, 4, 1, 1, 0, 3, 4, 4, 3, 1, 3, 4, 2, 0, 0, 2, 0, 1, 4, 2, 3, 4, 2, 0, 3, 0, 4, 1, 2, 4, 4, 3, 1, 0, 4, 2, 2, 0, 1, 1, 4, 4, 2, 2, 4, 0, 0, 1, 3, 2, 3, 1, 2, 3, 2, 0, 4, 2, 1, 2, 2, 2, 3, 2, 2, 4, 1, 2, 3, 4, 0, 0, 1, 4, 3, 0, 3, 2, 4, 3, 1, 3, 4, 4, 4, 1, 1, 3, 3, 0, 3, 3, 2, 0, 3, 4, 2, 2, 2, 0, 3, 4, 0, 0, 0, 2, 1, 1, 1, 1, 1, 2, 4, 2, 0, 1, 3, 3, 1, 0, 0, 1,  ...
# Predictions saved to prediction.csv

# %% [markdown]
# Validation

# %%
df_val = pd.read_csv(validation_file)

val_data = []
for idx, row in df_val.iterrows():
    img_name = row['image_id'] + '.png'
    label = row['label']
    img_path = os.path.join(val_dir, img_name)
    image = cv2.imread(img_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_resized = cv2.resize(image_rgb, (100, 100))
    
    normalized_image = cv2.normalize(image_resized.astype('float32'), None, 0, 1, cv2.NORM_MINMAX)
    image_tensor = torch.from_numpy(normalized_image).permute(2, 0, 1).float()
    val_data.append((image_tensor, label))

val_images = torch.stack([item[0] for item in val_data])
val_labels = torch.tensor([item[1] for item in val_data])

val_dataset = TensorDataset(val_images, val_labels)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=8)

model.eval()
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in val_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        preds = outputs.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

accuracy = correct / total
print(f'Validation Accuracy: {accuracy*100:.2f}%')

# 92.88%
# Out:
# Validation Accuracy: 91.76%
