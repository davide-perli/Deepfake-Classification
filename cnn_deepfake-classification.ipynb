# %% [markdown]
# Imports

# %%
import cv2
import matplotlib.pyplot as plt 
import pandas as pd
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import random
import numpy as np
import torchvision.transforms.v2 as T
import seaborn as sns
from PIL import Image, ImageEnhance
from torch.utils.data import TensorDataset, DataLoader
from os import listdir
from sklearn.metrics import confusion_matrix

# %% [markdown]
# Reading data

# %%
folder_dir = "/home/davide/Documents/Deepfake-Classification/deepfake-classification"
img_dir = "/home/davide/Documents/Deepfake-Classification/deepfake-classification/train"

test_dir = "/home/davide/Documents/Deepfake-Classification/deepfake-classification/test"
test_file = os.path.join(folder_dir, "test.csv")  

csv_file = os.path.join(folder_dir, "train.csv")

validation_file = os.path.join(folder_dir, "validation.csv")
val_dir = "/home/davide/Documents/Deepfake-Classification/deepfake-classification/validation"

# %% [markdown]
# Load Training Data

# %%
df_train = pd.read_csv(csv_file)

# %% [markdown]
# Data Augmentation

# %%
def augment_image(image):
    image_pil = Image.fromarray(image)
    
    image_pil = image_pil.transpose(Image.FLIP_LEFT_RIGHT)
    image_pil = image_pil.transpose(Image.FLIP_TOP_BOTTOM)

    image_pil = image_pil.rotate(40)

    enhancer = ImageEnhance.Brightness(image_pil)
    image_pil = enhancer.enhance(1.185)
    
    image_pil = ImageEnhance.Color(image_pil).enhance(0.8)
    image_pil = ImageEnhance.Sharpness(image_pil).enhance(0.968)

    return np.array(image_pil)

augmented_data = []
print(f"Training set size: {len(df_train)}")
for idx in range(len(df_train)):
    row = df_train.iloc[idx]
    img_path = os.path.join(img_dir, row['image_id'] + '.png')
    image = cv2.imread(img_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    image_resized = cv2.resize(image_rgb, (100, 100))
    
    augmented_image = augment_image(image_resized)
    
    normalized = cv2.normalize(augmented_image.astype('float32'), None, 0, 1, cv2.NORM_MINMAX)
    tensor_image = torch.from_numpy(normalized).permute(2, 0, 1).float()
    
    augmented_data.append((tensor_image, row['label']))

print(f"Finished generating augmented images")
# Out:
# Training set size: 12500
# Finished generating augmented images

# %% [markdown]
# Training

# %%
class NeuralNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1_1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1, bias=False)
        self.bn1_1 = nn.BatchNorm2d(32)
        self.conv1_2 = nn.Conv2d(32, 32, kernel_size=3, padding=1, bias=False)
        self.bn1_2 = nn.BatchNorm2d(32)

        self.conv2_1 = nn.Conv2d(32, 64, kernel_size=3, padding=1, bias=False)
        self.bn2_1 = nn.BatchNorm2d(64)
        self.conv2_2 = nn.Conv2d(64, 64, kernel_size=3, padding=1, bias=False)
        self.bn2_2 = nn.BatchNorm2d(64)

        self.conv3_1 = nn.Conv2d(64, 128, kernel_size=3, padding=1, bias=False)
        self.bn3_1 = nn.BatchNorm2d(128)
        self.conv3_2 = nn.Conv2d(128, 128, kernel_size=3, padding=1, bias=False)
        self.bn3_2 = nn.BatchNorm2d(128)
        self.conv3_3 = nn.Conv2d(128, 128, kernel_size=3, padding=1, bias=False)
        self.bn3_3 = nn.BatchNorm2d(128)

        self.conv4_1 = nn.Conv2d(128, 256, kernel_size=3, padding=1, bias=False)
        self.bn4_1 = nn.BatchNorm2d(256)
        self.conv4_2 = nn.Conv2d(256, 256, kernel_size=3, padding=1, bias=False)
        self.bn4_2 = nn.BatchNorm2d(256)
        self.conv4_3 = nn.Conv2d(256, 256, kernel_size=3, padding=1, bias=False)
        self.bn4_3 = nn.BatchNorm2d(256)

        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(0.5)

        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Linear(256, 10)

    def forward(self, x):
        
        x = F.relu(self.bn1_1(self.conv1_1(x)))
        x = F.relu(self.bn1_2(self.conv1_2(x)))
        x = self.pool(x)

        x = F.relu(self.bn2_1(self.conv2_1(x)))
        x = F.relu(self.bn2_2(self.conv2_2(x)))
        x = self.pool(x)

        x = F.relu(self.bn3_1(self.conv3_1(x)))
        x = F.relu(self.bn3_2(self.conv3_2(x)))
        x = F.relu(self.bn3_3(self.conv3_3(x)))
        x = self.pool(x)

        x = F.relu(self.bn4_1(self.conv4_1(x)))
        x = F.relu(self.bn4_2(self.conv4_2(x)))
        x = F.relu(self.bn4_3(self.conv4_3(x)))
        x = self.pool(x)

        x = self.global_avg_pool(x) 
        x = torch.flatten(x, 1)      
        x = self.dropout(x)
        x = self.fc(x)
        return x

    
model = NeuralNet()

data = []
for idx, row in df_train.iterrows():
    img_name = row['image_id'] + '.png'
    label = row['label']
    img_path = os.path.join(img_dir, img_name)
    image = cv2.imread(img_path)

    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    # height, width, channels = image_rgb.shape

    # print(f"Original image width: {width} pixels")   100
    # print(f"Original image height: {height} pixels") 100
    # print(f"Number of channels: {channels}")         3
    image_resized = cv2.resize(image_rgb, (100, 100))
    normalized_image = cv2.normalize(image_resized.astype('float32'), None, 0, 1, cv2.NORM_MINMAX)

    image_tensor = torch.from_numpy(normalized_image).permute(2, 0, 1).float()

    data.append((image_tensor, label))

data += augmented_data
print(f"Total training data size: {len(data)}")

images = torch.stack([item[0] for item in data])
labels = torch.tensor([item[1] for item in data])

dataset = TensorDataset(images, labels)
train_loader = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=8)

# optimizer = torch.optim.Adam(model.parameters(), lr=0.006, weight_decay=1e-5)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5)

# residual blocks and skip connection 

optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.82, weight_decay=1e-4, nesterov=True)
scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer, base_lr=0.001, max_lr=0.01, step_size_up=2000)

# 186
NUM_EPOCHS = 186
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")
model = model.to(device) 
loss_function = nn.CrossEntropyLoss() 

train_losses = []
train_accuracies = []

model.train(True)
for epoch in range(NUM_EPOCHS): 
    print(f"=== Epoch {epoch+1} ===")
    ####################
    running_loss = 0.0
    correct = 0
    total = 0
    ###################
    for i, (inputs, labels) in enumerate(train_loader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad(set_to_none=True)
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        scheduler.step()

#####################################################
        running_loss += loss.item() * inputs.size(0)
        predicted = outputs.argmax(dim=1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)
#####################################################

        if i % 100 == 0:
            print(f"Batch {i}, Loss: {loss.item():.4f}")

##################################################################################
    epoch_loss = running_loss / total
    epoch_acc = correct / total
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_acc)
    # scheduler.step(epoch_loss)
    print(f"Epoch {epoch+1} Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}")
    # if epoch_loss < 0.001:
    #     print(f"Stopping early at epoch {epoch+1} as loss is {epoch_loss: .4f}")
    #     break
##################################################################################
print('Finished training')
epochs = range(1, len(train_losses) + 1)
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_losses, 'b-', label='Training Loss')
plt.plot(epochs, train_accuracies, 'r-', label='Training Accuracy')
plt.xlabel('Epoch')
plt.title('Training Loss and Accuracy')
plt.legend()
plt.show()
# Out:
# Total training data size: 25000
# Device: cuda
# === Epoch 1 ===
# Batch 0, Loss: 2.8903
# Batch 100, Loss: 0.7790
# Batch 200, Loss: 0.7183
# Batch 300, Loss: 0.8281
# Batch 400, Loss: 0.5272
# Batch 500, Loss: 0.5883
# Batch 600, Loss: 0.6492
# Batch 700, Loss: 0.4905
# Epoch 1 Loss: 0.8321, Accuracy: 0.6771
# === Epoch 2 ===
# Batch 0, Loss: 0.6007
# Batch 100, Loss: 0.5347
# Batch 200, Loss: 0.5133
# Batch 300, Loss: 0.4601
# Batch 400, Loss: 0.4392
# Batch 500, Loss: 0.4619
# Batch 600, Loss: 0.6582
# Batch 700, Loss: 0.4825
# Epoch 2 Loss: 0.6412, Accuracy: 0.7538
# === Epoch 3 ===
# Batch 0, Loss: 1.0191
# Batch 100, Loss: 0.3907
# Batch 200, Loss: 0.6291
# Batch 300, Loss: 0.6179
# Batch 400, Loss: 0.6625
# Batch 500, Loss: 0.3605
# Batch 600, Loss: 0.5500
# Batch 700, Loss: 0.5098
# Epoch 3 Loss: 0.5694, Accuracy: 0.7844
# === Epoch 4 ===
# Batch 0, Loss: 0.8288
# Batch 100, Loss: 0.5939
# Batch 200, Loss: 0.4509
# Batch 300, Loss: 0.3378
# Batch 400, Loss: 0.4875
# Batch 500, Loss: 0.3682
# Batch 600, Loss: 0.3612
# Batch 700, Loss: 0.6118
# Epoch 4 Loss: 0.4834, Accuracy: 0.8165
# === Epoch 5 ===
# Batch 0, Loss: 0.4021
# Batch 100, Loss: 0.5276
# Batch 200, Loss: 0.5333
# Batch 300, Loss: 0.6606
# Batch 400, Loss: 0.3250
# Batch 500, Loss: 0.2654
# Batch 600, Loss: 0.3505
# Batch 700, Loss: 0.3503
# Epoch 5 Loss: 0.3957, Accuracy: 0.8504
# === Epoch 6 ===
# Batch 0, Loss: 0.2240
# Batch 100, Loss: 0.5436
# Batch 200, Loss: 0.2966
# Batch 300, Loss: 0.3741
# Batch 400, Loss: 0.6364
# Batch 500, Loss: 0.5119
# Batch 600, Loss: 0.3994
# Batch 700, Loss: 0.3423
# Epoch 6 Loss: 0.3572, Accuracy: 0.8673
# === Epoch 7 ===
# Batch 0, Loss: 0.4548
# Batch 100, Loss: 0.2758
# Batch 200, Loss: 0.3787
# Batch 300, Loss: 0.3543
# Batch 400, Loss: 0.5972
# Batch 500, Loss: 0.3053
# Batch 600, Loss: 0.2039
# Batch 700, Loss: 0.3273
# Epoch 7 Loss: 0.3975, Accuracy: 0.8498
# === Epoch 8 ===
# Batch 0, Loss: 0.3223
# Batch 100, Loss: 0.4186
# Batch 200, Loss: 0.5053
# Batch 300, Loss: 0.4908
# Batch 400, Loss: 0.3867
# Batch 500, Loss: 0.3778
# Batch 600, Loss: 0.4751
# Batch 700, Loss: 0.3420
# Epoch 8 Loss: 0.3997, Accuracy: 0.8501
# === Epoch 9 ===
# Batch 0, Loss: 0.5301
# Batch 100, Loss: 0.3051
# Batch 200, Loss: 0.3262
# Batch 300, Loss: 0.6051
# Batch 400, Loss: 0.3265
# Batch 500, Loss: 0.1660
# Batch 600, Loss: 0.2287
# Batch 700, Loss: 0.1658
# Epoch 9 Loss: 0.3531, Accuracy: 0.8659
# === Epoch 10 ===
# Batch 0, Loss: 0.2113
# Batch 100, Loss: 0.1315
# Batch 200, Loss: 0.1588
# Batch 300, Loss: 0.2896
# Batch 400, Loss: 0.2013
# Batch 500, Loss: 0.2834
# Batch 600, Loss: 0.5610
# Batch 700, Loss: 0.3899
# Epoch 10 Loss: 0.2870, Accuracy: 0.8907
# === Epoch 11 ===
# Batch 0, Loss: 0.4541
# Batch 100, Loss: 0.1281
# Batch 200, Loss: 0.2213
# Batch 300, Loss: 0.1493
# Batch 400, Loss: 0.1241
# Batch 500, Loss: 0.2965
# Batch 600, Loss: 0.0741
# Batch 700, Loss: 0.2021
# Epoch 11 Loss: 0.2390, Accuracy: 0.9114
# === Epoch 12 ===
# Batch 0, Loss: 0.2671
# Batch 100, Loss: 0.1936
# Batch 200, Loss: 0.2430
# Batch 300, Loss: 0.2070
# Batch 400, Loss: 0.3336
# Batch 500, Loss: 0.4045
# Batch 600, Loss: 0.2984
# Batch 700, Loss: 0.2134
# Epoch 12 Loss: 0.2925, Accuracy: 0.8908
# === Epoch 13 ===
# Batch 0, Loss: 0.1641
# Batch 100, Loss: 0.2812
# Batch 200, Loss: 0.0879
# Batch 300, Loss: 0.3735
# Batch 400, Loss: 0.2779
# Batch 500, Loss: 0.1511
# Batch 600, Loss: 0.3533
# Batch 700, Loss: 0.2850
# Epoch 13 Loss: 0.3136, Accuracy: 0.8823
# === Epoch 14 ===
# Batch 0, Loss: 0.2794
# Batch 100, Loss: 0.3392
# Batch 200, Loss: 0.2951
# Batch 300, Loss: 0.3667
# Batch 400, Loss: 0.1940
# Batch 500, Loss: 0.2492
# Batch 600, Loss: 0.2169
# Batch 700, Loss: 0.2603
# Epoch 14 Loss: 0.2788, Accuracy: 0.8939
# === Epoch 15 ===
# Batch 0, Loss: 0.1253
# Batch 100, Loss: 0.2103
# Batch 200, Loss: 0.1623
# Batch 300, Loss: 0.2486
# Batch 400, Loss: 0.2071
# Batch 500, Loss: 0.2974
# Batch 600, Loss: 0.1704
# Batch 700, Loss: 0.1607
# Epoch 15 Loss: 0.2143, Accuracy: 0.9202
# === Epoch 16 ===
# Batch 0, Loss: 0.1792
# Batch 100, Loss: 0.0802
# Batch 200, Loss: 0.1102
# Batch 300, Loss: 0.0384
# Batch 400, Loss: 0.1661
# Batch 500, Loss: 0.0734
# Batch 600, Loss: 0.6237
# Batch 700, Loss: 0.2738
# Epoch 16 Loss: 0.1561, Accuracy: 0.9416
# === Epoch 17 ===
# Batch 0, Loss: 0.2592
# Batch 100, Loss: 0.1046
# Batch 200, Loss: 0.1299
# Batch 300, Loss: 0.1830
# Batch 400, Loss: 0.1129
# Batch 500, Loss: 0.0765
# Batch 600, Loss: 0.0775
# Batch 700, Loss: 0.4247
# Epoch 17 Loss: 0.2142, Accuracy: 0.9205
# === Epoch 18 ===
# Batch 0, Loss: 0.3439
# Batch 100, Loss: 0.1098
# Batch 200, Loss: 0.1960
# Batch 300, Loss: 0.0824
# Batch 400, Loss: 0.1952
# Batch 500, Loss: 0.2779
# Batch 600, Loss: 0.3725
# Batch 700, Loss: 0.2267
# Epoch 18 Loss: 0.2439, Accuracy: 0.9107
# === Epoch 19 ===
# Batch 0, Loss: 0.3462
# Batch 100, Loss: 0.2928
# Batch 200, Loss: 0.1250
# Batch 300, Loss: 0.1684
# Batch 400, Loss: 0.3121
# Batch 500, Loss: 0.1528
# Batch 600, Loss: 0.2004
# Batch 700, Loss: 0.0524
# Epoch 19 Loss: 0.2148, Accuracy: 0.9188
# === Epoch 20 ===
# Batch 0, Loss: 0.2142
# Batch 100, Loss: 0.0523
# Batch 200, Loss: 0.1064
# Batch 300, Loss: 0.2420
# Batch 400, Loss: 0.3194
# Batch 500, Loss: 0.1636
# Batch 600, Loss: 0.0729
# Batch 700, Loss: 0.1892
# Epoch 20 Loss: 0.1588, Accuracy: 0.9409
# === Epoch 21 ===
# Batch 0, Loss: 0.3243
# Batch 100, Loss: 0.1079
# Batch 200, Loss: 0.0300
# Batch 300, Loss: 0.0229
# Batch 400, Loss: 0.1066
# Batch 500, Loss: 0.0361
# Batch 600, Loss: 0.0448
# Batch 700, Loss: 0.0778
# Epoch 21 Loss: 0.0980, Accuracy: 0.9664
# === Epoch 22 ===
# Batch 0, Loss: 0.0143
# Batch 100, Loss: 0.1330
# Batch 200, Loss: 0.2110
# Batch 300, Loss: 0.0880
# Batch 400, Loss: 0.2465
# Batch 500, Loss: 0.1878
# Batch 600, Loss: 0.1631
# Batch 700, Loss: 0.1659
# Epoch 22 Loss: 0.1433, Accuracy: 0.9482
# === Epoch 23 ===
# Batch 0, Loss: 0.0378
# Batch 100, Loss: 0.1665
# Batch 200, Loss: 0.0996
# Batch 300, Loss: 0.1064
# Batch 400, Loss: 0.3178
# Batch 500, Loss: 0.2632
# Batch 600, Loss: 0.0641
# Batch 700, Loss: 0.0818
# Epoch 23 Loss: 0.1841, Accuracy: 0.9318
# === Epoch 24 ===
# Batch 0, Loss: 0.2534
# Batch 100, Loss: 0.1234
# Batch 200, Loss: 0.0316
# Batch 300, Loss: 0.1559
# Batch 400, Loss: 0.1406
# Batch 500, Loss: 0.1564
# Batch 600, Loss: 0.1095
# Batch 700, Loss: 0.0768
# Epoch 24 Loss: 0.1711, Accuracy: 0.9358
# === Epoch 25 ===
# Batch 0, Loss: 0.1647
# Batch 100, Loss: 0.0777
# Batch 200, Loss: 0.0448
# Batch 300, Loss: 0.0425
# Batch 400, Loss: 0.2024
# Batch 500, Loss: 0.0810
# Batch 600, Loss: 0.0711
# Batch 700, Loss: 0.0743
# Epoch 25 Loss: 0.1130, Accuracy: 0.9606
# === Epoch 26 ===
# Batch 0, Loss: 0.0292
# Batch 100, Loss: 0.0993
# Batch 200, Loss: 0.0146
# Batch 300, Loss: 0.0345
# Batch 400, Loss: 0.0445
# Batch 500, Loss: 0.0196
# Batch 600, Loss: 0.3159
# Batch 700, Loss: 0.1502
# Epoch 26 Loss: 0.0595, Accuracy: 0.9810
# === Epoch 27 ===
# Batch 0, Loss: 0.1423
# Batch 100, Loss: 0.0043
# Batch 200, Loss: 0.0057
# Batch 300, Loss: 0.0449
# Batch 400, Loss: 0.0035
# Batch 500, Loss: 0.0340
# Batch 600, Loss: 0.1649
# Batch 700, Loss: 0.1134
# Epoch 27 Loss: 0.0920, Accuracy: 0.9671
# === Epoch 28 ===
# Batch 0, Loss: 0.1148
# Batch 100, Loss: 0.1018
# Batch 200, Loss: 0.4869
# Batch 300, Loss: 0.0887
# Batch 400, Loss: 0.0515
# Batch 500, Loss: 0.0212
# Batch 600, Loss: 0.5376
# Batch 700, Loss: 0.3776
# Epoch 28 Loss: 0.1509, Accuracy: 0.9465
# === Epoch 29 ===
# Batch 0, Loss: 0.2364
# Batch 100, Loss: 0.1279
# Batch 200, Loss: 0.0275
# Batch 300, Loss: 0.0551
# Batch 400, Loss: 0.0488
# Batch 500, Loss: 0.0769
# Batch 600, Loss: 0.2115
# Batch 700, Loss: 0.1013
# Epoch 29 Loss: 0.1312, Accuracy: 0.9522
# === Epoch 30 ===
# Batch 0, Loss: 0.0244
# Batch 100, Loss: 0.0469
# Batch 200, Loss: 0.0596
# Batch 300, Loss: 0.2169
# Batch 400, Loss: 0.0132
# Batch 500, Loss: 0.2305
# Batch 600, Loss: 0.1224
# Batch 700, Loss: 0.0148
# Epoch 30 Loss: 0.0846, Accuracy: 0.9691
# === Epoch 31 ===
# Batch 0, Loss: 0.1042
# Batch 100, Loss: 0.0972
# Batch 200, Loss: 0.0850
# Batch 300, Loss: 0.0095
# Batch 400, Loss: 0.0260
# Batch 500, Loss: 0.0342
# Batch 600, Loss: 0.0335
# Batch 700, Loss: 0.0369
# Epoch 31 Loss: 0.0414, Accuracy: 0.9861
# === Epoch 32 ===
# Batch 0, Loss: 0.0214
# Batch 100, Loss: 0.0320
# Batch 200, Loss: 0.0034
# Batch 300, Loss: 0.0272
# Batch 400, Loss: 0.1241
# Batch 500, Loss: 0.0960
# Batch 600, Loss: 0.0289
# Batch 700, Loss: 0.0394
# Epoch 32 Loss: 0.0477, Accuracy: 0.9842
# === Epoch 33 ===
# Batch 0, Loss: 0.0490
# Batch 100, Loss: 0.0408
# Batch 200, Loss: 0.0768
# Batch 300, Loss: 0.0808
# Batch 400, Loss: 0.0651
# Batch 500, Loss: 0.1308
# Batch 600, Loss: 0.1005
# Batch 700, Loss: 0.0802
# Epoch 33 Loss: 0.1011, Accuracy: 0.9632
# === Epoch 34 ===
# Batch 0, Loss: 0.2437
# Batch 100, Loss: 0.0188
# Batch 200, Loss: 0.0698
# Batch 300, Loss: 0.0777
# Batch 400, Loss: 0.1582
# Batch 500, Loss: 0.2258
# Batch 600, Loss: 0.0566
# Batch 700, Loss: 0.0981
# Epoch 34 Loss: 0.1219, Accuracy: 0.9554
# === Epoch 35 ===
# Batch 0, Loss: 0.1966
# Batch 100, Loss: 0.1555
# Batch 200, Loss: 0.0976
# Batch 300, Loss: 0.1149
# Batch 400, Loss: 0.0125
# Batch 500, Loss: 0.0508
# Batch 600, Loss: 0.0749
# Batch 700, Loss: 0.0125
# Epoch 35 Loss: 0.0744, Accuracy: 0.9734
# === Epoch 36 ===
# Batch 0, Loss: 0.0082
# Batch 100, Loss: 0.1863
# Batch 200, Loss: 0.0293
# Batch 300, Loss: 0.1228
# Batch 400, Loss: 0.0078
# Batch 500, Loss: 0.0063
# Batch 600, Loss: 0.1039
# Batch 700, Loss: 0.0506
# Epoch 36 Loss: 0.0299, Accuracy: 0.9917
# === Epoch 37 ===
# Batch 0, Loss: 0.0032
# Batch 100, Loss: 0.0232
# Batch 200, Loss: 0.0134
# Batch 300, Loss: 0.0539
# Batch 400, Loss: 0.0081
# Batch 500, Loss: 0.0033
# Batch 600, Loss: 0.0062
# Batch 700, Loss: 0.0415
# Epoch 37 Loss: 0.0309, Accuracy: 0.9897
# === Epoch 38 ===
# Batch 0, Loss: 0.0071
# Batch 100, Loss: 0.0097
# Batch 200, Loss: 0.0165
# Batch 300, Loss: 0.0498
# Batch 400, Loss: 0.1369
# Batch 500, Loss: 0.1671
# Batch 600, Loss: 0.1277
# Batch 700, Loss: 0.1717
# Epoch 38 Loss: 0.0716, Accuracy: 0.9742
# === Epoch 39 ===
# Batch 0, Loss: 0.2994
# Batch 100, Loss: 0.0694
# Batch 200, Loss: 0.0176
# Batch 300, Loss: 0.0328
# Batch 400, Loss: 0.0249
# Batch 500, Loss: 0.1755
# Batch 600, Loss: 0.0676
# Batch 700, Loss: 0.0926
# Epoch 39 Loss: 0.0986, Accuracy: 0.9649
# === Epoch 40 ===
# Batch 0, Loss: 0.0167
# Batch 100, Loss: 0.0448
# Batch 200, Loss: 0.0989
# Batch 300, Loss: 0.0138
# Batch 400, Loss: 0.0081
# Batch 500, Loss: 0.0408
# Batch 600, Loss: 0.0409
# Batch 700, Loss: 0.0131
# Epoch 40 Loss: 0.0507, Accuracy: 0.9834
# === Epoch 41 ===
# Batch 0, Loss: 0.0443
# Batch 100, Loss: 0.0270
# Batch 200, Loss: 0.1119
# Batch 300, Loss: 0.0104
# Batch 400, Loss: 0.0016
# Batch 500, Loss: 0.0175
# Batch 600, Loss: 0.0220
# Batch 700, Loss: 0.0053
# Epoch 41 Loss: 0.0266, Accuracy: 0.9918
# === Epoch 42 ===
# Batch 0, Loss: 0.0055
# Batch 100, Loss: 0.0161
# Batch 200, Loss: 0.0070
# Batch 300, Loss: 0.0050
# Batch 400, Loss: 0.1395
# Batch 500, Loss: 0.0400
# Batch 600, Loss: 0.0036
# Batch 700, Loss: 0.0037
# Epoch 42 Loss: 0.0166, Accuracy: 0.9954
# === Epoch 43 ===
# Batch 0, Loss: 0.0023
# Batch 100, Loss: 0.0380
# Batch 200, Loss: 0.0144
# Batch 300, Loss: 0.0042
# Batch 400, Loss: 0.0107
# Batch 500, Loss: 0.0128
# Batch 600, Loss: 0.0198
# Batch 700, Loss: 0.0318
# Epoch 43 Loss: 0.0385, Accuracy: 0.9862
# === Epoch 44 ===
# Batch 0, Loss: 0.1308
# Batch 100, Loss: 0.0793
# Batch 200, Loss: 0.1834
# Batch 300, Loss: 0.0563
# Batch 400, Loss: 0.0167
# Batch 500, Loss: 0.0327
# Batch 600, Loss: 0.0455
# Batch 700, Loss: 0.0640
# Epoch 44 Loss: 0.0842, Accuracy: 0.9706
# === Epoch 45 ===
# Batch 0, Loss: 0.2246
# Batch 100, Loss: 0.0228
# Batch 200, Loss: 0.1983
# Batch 300, Loss: 0.0059
# Batch 400, Loss: 0.0177
# Batch 500, Loss: 0.0526
# Batch 600, Loss: 0.0087
# Batch 700, Loss: 0.0765
# Epoch 45 Loss: 0.0535, Accuracy: 0.9810
# === Epoch 46 ===
# Batch 0, Loss: 0.0044
# Batch 100, Loss: 0.0038
# Batch 200, Loss: 0.0172
# Batch 300, Loss: 0.0039
# Batch 400, Loss: 0.0077
# Batch 500, Loss: 0.0097
# Batch 600, Loss: 0.0028
# Batch 700, Loss: 0.0344
# Epoch 46 Loss: 0.0217, Accuracy: 0.9936
# === Epoch 47 ===
# Batch 0, Loss: 0.0305
# Batch 100, Loss: 0.0176
# Batch 200, Loss: 0.0018
# Batch 300, Loss: 0.0008
# Batch 400, Loss: 0.0074
# Batch 500, Loss: 0.0008
# Batch 600, Loss: 0.0538
# Batch 700, Loss: 0.0342
# Epoch 47 Loss: 0.0128, Accuracy: 0.9965
# === Epoch 48 ===
# Batch 0, Loss: 0.0053
# Batch 100, Loss: 0.0056
# Batch 200, Loss: 0.0022
# Batch 300, Loss: 0.0007
# Batch 400, Loss: 0.0405
# Batch 500, Loss: 0.0511
# Batch 600, Loss: 0.0041
# Batch 700, Loss: 0.0286
# Epoch 48 Loss: 0.0258, Accuracy: 0.9920
# === Epoch 49 ===
# Batch 0, Loss: 0.0080
# Batch 100, Loss: 0.0949
# Batch 200, Loss: 0.0742
# Batch 300, Loss: 0.0867
# Batch 400, Loss: 0.2436
# Batch 500, Loss: 0.0403
# Batch 600, Loss: 0.2472
# Batch 700, Loss: 0.0337
# Epoch 49 Loss: 0.0761, Accuracy: 0.9736
# === Epoch 50 ===
# Batch 0, Loss: 0.0592
# Batch 100, Loss: 0.0292
# Batch 200, Loss: 0.0271
# Batch 300, Loss: 0.1124
# Batch 400, Loss: 0.0018
# Batch 500, Loss: 0.0034
# Batch 600, Loss: 0.0969
# Batch 700, Loss: 0.0058
# Epoch 50 Loss: 0.0393, Accuracy: 0.9868
# === Epoch 51 ===
# Batch 0, Loss: 0.0029
# Batch 100, Loss: 0.0052
# Batch 200, Loss: 0.0140
# Batch 300, Loss: 0.0394
# Batch 400, Loss: 0.0063
# Batch 500, Loss: 0.0023
# Batch 600, Loss: 0.0022
# Batch 700, Loss: 0.0042
# Epoch 51 Loss: 0.0175, Accuracy: 0.9948
# === Epoch 52 ===
# Batch 0, Loss: 0.0013
# Batch 100, Loss: 0.0028
# Batch 200, Loss: 0.0790
# Batch 300, Loss: 0.0013
# Batch 400, Loss: 0.0003
# Batch 500, Loss: 0.0016
# Batch 600, Loss: 0.0011
# Batch 700, Loss: 0.0020
# Epoch 52 Loss: 0.0087, Accuracy: 0.9978
# === Epoch 53 ===
# Batch 0, Loss: 0.0168
# Batch 100, Loss: 0.0067
# Batch 200, Loss: 0.0066
# Batch 300, Loss: 0.0028
# Batch 400, Loss: 0.0067
# Batch 500, Loss: 0.0144
# Batch 600, Loss: 0.0021
# Batch 700, Loss: 0.0047
# Epoch 53 Loss: 0.0181, Accuracy: 0.9946
# === Epoch 54 ===
# Batch 0, Loss: 0.1125
# Batch 100, Loss: 0.0760
# Batch 200, Loss: 0.0122
# Batch 300, Loss: 0.0155
# Batch 400, Loss: 0.0947
# Batch 500, Loss: 0.0325
# Batch 600, Loss: 0.0967
# Batch 700, Loss: 0.1258
# Epoch 54 Loss: 0.0696, Accuracy: 0.9765
# === Epoch 55 ===
# Batch 0, Loss: 0.1802
# Batch 100, Loss: 0.0395
# Batch 200, Loss: 0.0043
# Batch 300, Loss: 0.0036
# Batch 400, Loss: 0.0536
# Batch 500, Loss: 0.0148
# Batch 600, Loss: 0.0263
# Batch 700, Loss: 0.2617
# Epoch 55 Loss: 0.0470, Accuracy: 0.9839
# === Epoch 56 ===
# Batch 0, Loss: 0.1233
# Batch 100, Loss: 0.0248
# Batch 200, Loss: 0.0070
# Batch 300, Loss: 0.0031
# Batch 400, Loss: 0.0120
# Batch 500, Loss: 0.0089
# Batch 600, Loss: 0.0921
# Batch 700, Loss: 0.0047
# Epoch 56 Loss: 0.0184, Accuracy: 0.9946
# === Epoch 57 ===
# Batch 0, Loss: 0.0008
# Batch 100, Loss: 0.0335
# Batch 200, Loss: 0.0027
# Batch 300, Loss: 0.0086
# Batch 400, Loss: 0.0006
# Batch 500, Loss: 0.0134
# Batch 600, Loss: 0.0086
# Batch 700, Loss: 0.0009
# Epoch 57 Loss: 0.0070, Accuracy: 0.9985
# === Epoch 58 ===
# Batch 0, Loss: 0.0064
# Batch 100, Loss: 0.0276
# Batch 200, Loss: 0.0014
# Batch 300, Loss: 0.0325
# Batch 400, Loss: 0.0091
# Batch 500, Loss: 0.0008
# Batch 600, Loss: 0.0595
# Batch 700, Loss: 0.0383
# Epoch 58 Loss: 0.0160, Accuracy: 0.9951
# === Epoch 59 ===
# Batch 0, Loss: 0.0637
# Batch 100, Loss: 0.0036
# Batch 200, Loss: 0.0256
# Batch 300, Loss: 0.2218
# Batch 400, Loss: 0.0249
# Batch 500, Loss: 0.0097
# Batch 600, Loss: 0.0804
# Batch 700, Loss: 0.2002
# Epoch 59 Loss: 0.0519, Accuracy: 0.9821
# === Epoch 60 ===
# Batch 0, Loss: 0.0177
# Batch 100, Loss: 0.0108
# Batch 200, Loss: 0.0588
# Batch 300, Loss: 0.0130
# Batch 400, Loss: 0.0068
# Batch 500, Loss: 0.0013
# Batch 600, Loss: 0.0031
# Batch 700, Loss: 0.0089
# Epoch 60 Loss: 0.0298, Accuracy: 0.9904
# === Epoch 61 ===
# Batch 0, Loss: 0.0013
# Batch 100, Loss: 0.0019
# Batch 200, Loss: 0.0183
# Batch 300, Loss: 0.0019
# Batch 400, Loss: 0.0050
# Batch 500, Loss: 0.0009
# Batch 600, Loss: 0.0002
# Batch 700, Loss: 0.0049
# Epoch 61 Loss: 0.0159, Accuracy: 0.9951
# === Epoch 62 ===
# Batch 0, Loss: 0.0198
# Batch 100, Loss: 0.0076
# Batch 200, Loss: 0.0211
# Batch 300, Loss: 0.0010
# Batch 400, Loss: 0.0020
# Batch 500, Loss: 0.0004
# Batch 600, Loss: 0.0020
# Batch 700, Loss: 0.0006
# Epoch 62 Loss: 0.0083, Accuracy: 0.9978
# === Epoch 63 ===
# Batch 0, Loss: 0.0018
# Batch 100, Loss: 0.0690
# Batch 200, Loss: 0.0128
# Batch 300, Loss: 0.0103
# Batch 400, Loss: 0.0462
# Batch 500, Loss: 0.0003
# Batch 600, Loss: 0.0008
# Batch 700, Loss: 0.5285
# Epoch 63 Loss: 0.0122, Accuracy: 0.9964
# === Epoch 64 ===
# Batch 0, Loss: 1.3987
# Batch 100, Loss: 0.0042
# Batch 200, Loss: 0.0351
# Batch 300, Loss: 0.1363
# Batch 400, Loss: 0.0506
# Batch 500, Loss: 0.0424
# Batch 600, Loss: 0.0100
# Batch 700, Loss: 0.0462
# Epoch 64 Loss: 0.0632, Accuracy: 0.9792
# === Epoch 65 ===
# Batch 0, Loss: 0.0409
# Batch 100, Loss: 0.0142
# Batch 200, Loss: 0.0296
# Batch 300, Loss: 0.0619
# Batch 400, Loss: 0.0028
# Batch 500, Loss: 0.1077
# Batch 600, Loss: 0.0640
# Batch 700, Loss: 0.0064
# Epoch 65 Loss: 0.0409, Accuracy: 0.9863
# === Epoch 66 ===
# Batch 0, Loss: 0.0352
# Batch 100, Loss: 0.1457
# Batch 200, Loss: 0.0117
# Batch 300, Loss: 0.0393
# Batch 400, Loss: 0.0022
# Batch 500, Loss: 0.0007
# Batch 600, Loss: 0.0285
# Batch 700, Loss: 0.0004
# Epoch 66 Loss: 0.0141, Accuracy: 0.9958
# === Epoch 67 ===
# Batch 0, Loss: 0.0011
# Batch 100, Loss: 0.0005
# Batch 200, Loss: 0.0017
# Batch 300, Loss: 0.0055
# Batch 400, Loss: 0.0102
# Batch 500, Loss: 0.0009
# Batch 600, Loss: 0.0019
# Batch 700, Loss: 0.0017
# Epoch 67 Loss: 0.0108, Accuracy: 0.9970
# === Epoch 68 ===
# Batch 0, Loss: 0.0011
# Batch 100, Loss: 0.0011
# Batch 200, Loss: 0.0002
# Batch 300, Loss: 0.0005
# Batch 400, Loss: 0.0036
# Batch 500, Loss: 0.0002
# Batch 600, Loss: 0.0012
# Batch 700, Loss: 0.0004
# Epoch 68 Loss: 0.0068, Accuracy: 0.9983
# === Epoch 69 ===
# Batch 0, Loss: 0.0052
# Batch 100, Loss: 0.0041
# Batch 200, Loss: 0.0022
# Batch 300, Loss: 0.0085
# Batch 400, Loss: 0.0021
# Batch 500, Loss: 0.0412
# Batch 600, Loss: 0.0088
# Batch 700, Loss: 0.0026
# Epoch 69 Loss: 0.0196, Accuracy: 0.9934
# === Epoch 70 ===
# Batch 0, Loss: 0.2091
# Batch 100, Loss: 0.0293
# Batch 200, Loss: 0.0217
# Batch 300, Loss: 0.0433
# Batch 400, Loss: 0.2040
# Batch 500, Loss: 0.0298
# Batch 600, Loss: 0.0997
# Batch 700, Loss: 0.0031
# Epoch 70 Loss: 0.0565, Accuracy: 0.9808
# === Epoch 71 ===
# Batch 0, Loss: 0.0060
# Batch 100, Loss: 0.0025
# Batch 200, Loss: 0.0012
# Batch 300, Loss: 0.0066
# Batch 400, Loss: 0.0781
# Batch 500, Loss: 0.0006
# Batch 600, Loss: 0.0028
# Batch 700, Loss: 0.0058
# Epoch 71 Loss: 0.0134, Accuracy: 0.9964
# === Epoch 72 ===
# Batch 0, Loss: 0.0016
# Batch 100, Loss: 0.0037
# Batch 200, Loss: 0.0005
# Batch 300, Loss: 0.0019
# Batch 400, Loss: 0.0095
# Batch 500, Loss: 0.0007
# Batch 600, Loss: 0.0049
# Batch 700, Loss: 0.0061
# Epoch 72 Loss: 0.0056, Accuracy: 0.9987
# === Epoch 73 ===
# Batch 0, Loss: 0.0024
# Batch 100, Loss: 0.0009
# Batch 200, Loss: 0.0008
# Batch 300, Loss: 0.0045
# Batch 400, Loss: 0.0121
# Batch 500, Loss: 0.0013
# Batch 600, Loss: 0.0069
# Batch 700, Loss: 0.0040
# Epoch 73 Loss: 0.0053, Accuracy: 0.9989
# === Epoch 74 ===
# Batch 0, Loss: 0.0014
# Batch 100, Loss: 0.0009
# Batch 200, Loss: 0.0028
# Batch 300, Loss: 0.0045
# Batch 400, Loss: 0.0020
# Batch 500, Loss: 0.0753
# Batch 600, Loss: 0.0010
# Batch 700, Loss: 0.0020
# Epoch 74 Loss: 0.0138, Accuracy: 0.9964
# === Epoch 75 ===
# Batch 0, Loss: 0.0462
# Batch 100, Loss: 0.0006
# Batch 200, Loss: 0.0122
# Batch 300, Loss: 0.0716
# Batch 400, Loss: 0.1588
# Batch 500, Loss: 0.0126
# Batch 600, Loss: 0.0042
# Batch 700, Loss: 0.0083
# Epoch 75 Loss: 0.0265, Accuracy: 0.9912
# === Epoch 76 ===
# Batch 0, Loss: 0.1027
# Batch 100, Loss: 0.0091
# Batch 200, Loss: 0.0090
# Batch 300, Loss: 0.0087
# Batch 400, Loss: 0.1290
# Batch 500, Loss: 0.0304
# Batch 600, Loss: 0.0037
# Batch 700, Loss: 0.0324
# Epoch 76 Loss: 0.0171, Accuracy: 0.9944
# === Epoch 77 ===
# Batch 0, Loss: 0.0007
# Batch 100, Loss: 0.0020
# Batch 200, Loss: 0.0015
# Batch 300, Loss: 0.0029
# Batch 400, Loss: 0.0005
# Batch 500, Loss: 0.0019
# Batch 600, Loss: 0.0036
# Batch 700, Loss: 0.0002
# Epoch 77 Loss: 0.0052, Accuracy: 0.9986
# === Epoch 78 ===
# Batch 0, Loss: 0.0006
# Batch 100, Loss: 0.0001
# Batch 200, Loss: 0.0019
# Batch 300, Loss: 0.0013
# Batch 400, Loss: 0.0057
# Batch 500, Loss: 0.0028
# Batch 600, Loss: 0.0009
# Batch 700, Loss: 0.0015
# Epoch 78 Loss: 0.0035, Accuracy: 0.9993
# === Epoch 79 ===
# Batch 0, Loss: 0.0002
# Batch 100, Loss: 0.0114
# Batch 200, Loss: 0.0016
# Batch 300, Loss: 0.0016
# Batch 400, Loss: 0.0008
# Batch 500, Loss: 0.0004
# Batch 600, Loss: 0.0129
# Batch 700, Loss: 0.0101
# Epoch 79 Loss: 0.0076, Accuracy: 0.9983
# === Epoch 80 ===
# Batch 0, Loss: 0.2481
# Batch 100, Loss: 0.0222
# Batch 200, Loss: 0.0042
# Batch 300, Loss: 0.0160
# Batch 400, Loss: 0.0278
# Batch 500, Loss: 0.0074
# Batch 600, Loss: 0.0177
# Batch 700, Loss: 0.0129
# Epoch 80 Loss: 0.0634, Accuracy: 0.9790
# === Epoch 81 ===
# Batch 0, Loss: 0.0030
# Batch 100, Loss: 0.0567
# Batch 200, Loss: 0.0093
# Batch 300, Loss: 0.0519
# Batch 400, Loss: 0.0148
# Batch 500, Loss: 0.0012
# Batch 600, Loss: 0.0007
# Batch 700, Loss: 0.0006
# Epoch 81 Loss: 0.0194, Accuracy: 0.9938
# === Epoch 82 ===
# Batch 0, Loss: 0.0141
# Batch 100, Loss: 0.0012
# Batch 200, Loss: 0.0082
# Batch 300, Loss: 0.0157
# Batch 400, Loss: 0.0002
# Batch 500, Loss: 0.0035
# Batch 600, Loss: 0.0082
# Batch 700, Loss: 0.0013
# Epoch 82 Loss: 0.0088, Accuracy: 0.9978
# === Epoch 83 ===
# Batch 0, Loss: 0.0169
# Batch 100, Loss: 0.0166
# Batch 200, Loss: 0.0019
# Batch 300, Loss: 0.0084
# Batch 400, Loss: 0.0090
# Batch 500, Loss: 0.0104
# Batch 600, Loss: 0.0111
# Batch 700, Loss: 0.0003
# Epoch 83 Loss: 0.0052, Accuracy: 0.9988
# === Epoch 84 ===
# Batch 0, Loss: 0.0002
# Batch 100, Loss: 0.0019
# Batch 200, Loss: 0.0006
# Batch 300, Loss: 0.0009
# Batch 400, Loss: 0.0066
# Batch 500, Loss: 0.0051
# Batch 600, Loss: 0.0093
# Batch 700, Loss: 0.0311
# Epoch 84 Loss: 0.0069, Accuracy: 0.9984
# === Epoch 85 ===
# Batch 0, Loss: 0.0352
# Batch 100, Loss: 0.0029
# Batch 200, Loss: 0.0145
# Batch 300, Loss: 0.0014
# Batch 400, Loss: 0.0108
# Batch 500, Loss: 0.0057
# Batch 600, Loss: 0.0029
# Batch 700, Loss: 0.0025
# Epoch 85 Loss: 0.0329, Accuracy: 0.9888
# === Epoch 86 ===
# Batch 0, Loss: 0.0252
# Batch 100, Loss: 0.0054
# Batch 200, Loss: 0.0065
# Batch 300, Loss: 0.0010
# Batch 400, Loss: 0.0193
# Batch 500, Loss: 0.0024
# Batch 600, Loss: 0.0027
# Batch 700, Loss: 0.0065
# Epoch 86 Loss: 0.0182, Accuracy: 0.9943
# === Epoch 87 ===
# Batch 0, Loss: 0.0082
# Batch 100, Loss: 0.0032
# Batch 200, Loss: 0.0059
# Batch 300, Loss: 0.0005
# Batch 400, Loss: 0.0035
# Batch 500, Loss: 0.0002
# Batch 600, Loss: 0.0097
# Batch 700, Loss: 0.0060
# Epoch 87 Loss: 0.0069, Accuracy: 0.9981
# === Epoch 88 ===
# Batch 0, Loss: 0.0003
# Batch 100, Loss: 0.0008
# Batch 200, Loss: 0.0018
# Batch 300, Loss: 0.0037
# Batch 400, Loss: 0.0025
# Batch 500, Loss: 0.0021
# Batch 600, Loss: 0.0024
# Batch 700, Loss: 0.0130
# Epoch 88 Loss: 0.0034, Accuracy: 0.9993
# === Epoch 89 ===
# Batch 0, Loss: 0.0027
# Batch 100, Loss: 0.0060
# Batch 200, Loss: 0.0022
# Batch 300, Loss: 0.0009
# Batch 400, Loss: 0.0014
# Batch 500, Loss: 0.0037
# Batch 600, Loss: 0.0045
# Batch 700, Loss: 0.0019
# Epoch 89 Loss: 0.0062, Accuracy: 0.9985
# === Epoch 90 ===
# Batch 0, Loss: 0.0021
# Batch 100, Loss: 0.0105
# Batch 200, Loss: 0.0052
# Batch 300, Loss: 0.0053
# Batch 400, Loss: 0.0027
# Batch 500, Loss: 0.0009
# Batch 600, Loss: 0.0031
# Batch 700, Loss: 0.0766
# Epoch 90 Loss: 0.0124, Accuracy: 0.9963
# === Epoch 91 ===
# Batch 0, Loss: 0.4548
# Batch 100, Loss: 0.0174
# Batch 200, Loss: 0.1616
# Batch 300, Loss: 0.0079
# Batch 400, Loss: 0.0036
# Batch 500, Loss: 0.0008
# Batch 600, Loss: 0.0057
# Batch 700, Loss: 0.0006
# Epoch 91 Loss: 0.0278, Accuracy: 0.9905
# === Epoch 92 ===
# Batch 0, Loss: 0.0085
# Batch 100, Loss: 0.0147
# Batch 200, Loss: 0.0012
# Batch 300, Loss: 0.0010
# Batch 400, Loss: 0.0111
# Batch 500, Loss: 0.0031
# Batch 600, Loss: 0.0013
# Batch 700, Loss: 0.1716
# Epoch 92 Loss: 0.0066, Accuracy: 0.9985
# === Epoch 93 ===
# Batch 0, Loss: 0.0002
# Batch 100, Loss: 0.0005
# Batch 200, Loss: 0.0006
# Batch 300, Loss: 0.0007
# Batch 400, Loss: 0.0019
# Batch 500, Loss: 0.0011
# Batch 600, Loss: 0.0194
# Batch 700, Loss: 0.0002
# Epoch 93 Loss: 0.0036, Accuracy: 0.9992
# === Epoch 94 ===
# Batch 0, Loss: 0.0012
# Batch 100, Loss: 0.0022
# Batch 200, Loss: 0.0078
# Batch 300, Loss: 0.0010
# Batch 400, Loss: 0.0023
# Batch 500, Loss: 0.0036
# Batch 600, Loss: 0.0052
# Batch 700, Loss: 0.0067
# Epoch 94 Loss: 0.0083, Accuracy: 0.9978
# === Epoch 95 ===
# Batch 0, Loss: 0.0027
# Batch 100, Loss: 0.0146
# Batch 200, Loss: 0.0005
# Batch 300, Loss: 0.0580
# Batch 400, Loss: 0.0598
# Batch 500, Loss: 0.0020
# Batch 600, Loss: 0.0331
# Batch 700, Loss: 0.0051
# Epoch 95 Loss: 0.0106, Accuracy: 0.9967
# === Epoch 96 ===
# Batch 0, Loss: 0.0057
# Batch 100, Loss: 0.0138
# Batch 200, Loss: 0.0021
# Batch 300, Loss: 0.0278
# Batch 400, Loss: 0.1218
# Batch 500, Loss: 0.0121
# Batch 600, Loss: 0.0007
# Batch 700, Loss: 0.0016
# Epoch 96 Loss: 0.0165, Accuracy: 0.9942
# === Epoch 97 ===
# Batch 0, Loss: 0.0005
# Batch 100, Loss: 0.0001
# Batch 200, Loss: 0.0058
# Batch 300, Loss: 0.0029
# Batch 400, Loss: 0.0003
# Batch 500, Loss: 0.0019
# Batch 600, Loss: 0.0006
# Batch 700, Loss: 0.0026
# Epoch 97 Loss: 0.0056, Accuracy: 0.9986
# === Epoch 98 ===
# Batch 0, Loss: 0.0013
# Batch 100, Loss: 0.0014
# Batch 200, Loss: 0.0031
# Batch 300, Loss: 0.0006
# Batch 400, Loss: 0.0006
# Batch 500, Loss: 0.0012
# Batch 600, Loss: 0.0013
# Batch 700, Loss: 0.0003
# Epoch 98 Loss: 0.0029, Accuracy: 0.9995
# === Epoch 99 ===
# Batch 0, Loss: 0.0001
# Batch 100, Loss: 0.0014
# Batch 200, Loss: 0.0004
# Batch 300, Loss: 0.0011
# Batch 400, Loss: 0.0013
# Batch 500, Loss: 0.0018
# Batch 600, Loss: 0.0023
# Batch 700, Loss: 0.0002
# Epoch 99 Loss: 0.0028, Accuracy: 0.9996
# === Epoch 100 ===
# Batch 0, Loss: 0.0003
# Batch 100, Loss: 0.0016
# Batch 200, Loss: 0.0015
# Batch 300, Loss: 0.0009
# Batch 400, Loss: 0.0011
# Batch 500, Loss: 0.0004
# Batch 600, Loss: 0.0025
# Batch 700, Loss: 0.0095
# Epoch 100 Loss: 0.0143, Accuracy: 0.9950
# === Epoch 101 ===
# Batch 0, Loss: 0.0845
# Batch 100, Loss: 0.0022
# Batch 200, Loss: 0.1236
# Batch 300, Loss: 0.0087
# Batch 400, Loss: 0.0261
# Batch 500, Loss: 0.0421
# Batch 600, Loss: 0.0016
# Batch 700, Loss: 0.0103
# Epoch 101 Loss: 0.0256, Accuracy: 0.9914
# === Epoch 102 ===
# Batch 0, Loss: 0.0004
# Batch 100, Loss: 0.0013
# Batch 200, Loss: 0.0009
# Batch 300, Loss: 0.0006
# Batch 400, Loss: 0.0055
# Batch 500, Loss: 0.0007
# Batch 600, Loss: 0.0087
# Batch 700, Loss: 0.0055
# Epoch 102 Loss: 0.0104, Accuracy: 0.9970
# === Epoch 103 ===
# Batch 0, Loss: 0.0003
# Batch 100, Loss: 0.0013
# Batch 200, Loss: 0.0056
# Batch 300, Loss: 0.0006
# Batch 400, Loss: 0.0005
# Batch 500, Loss: 0.0002
# Batch 600, Loss: 0.0005
# Batch 700, Loss: 0.0020
# Epoch 103 Loss: 0.0032, Accuracy: 0.9994
# === Epoch 104 ===
# Batch 0, Loss: 0.0008
# Batch 100, Loss: 0.0037
# Batch 200, Loss: 0.0148
# Batch 300, Loss: 0.0076
# Batch 400, Loss: 0.0044
# Batch 500, Loss: 0.0003
# Batch 600, Loss: 0.0011
# Batch 700, Loss: 0.0007
# Epoch 104 Loss: 0.0046, Accuracy: 0.9988
# === Epoch 105 ===
# Batch 0, Loss: 0.0006
# Batch 100, Loss: 0.0024
# Batch 200, Loss: 0.0038
# Batch 300, Loss: 0.1952
# Batch 400, Loss: 0.0122
# Batch 500, Loss: 0.0010
# Batch 600, Loss: 0.0055
# Batch 700, Loss: 0.0588
# Epoch 105 Loss: 0.0245, Accuracy: 0.9920
# === Epoch 106 ===
# Batch 0, Loss: 0.0518
# Batch 100, Loss: 0.0907
# Batch 200, Loss: 0.0191
# Batch 300, Loss: 0.0145
# Batch 400, Loss: 0.0024
# Batch 500, Loss: 0.0253
# Batch 600, Loss: 0.0076
# Batch 700, Loss: 0.0010
# Epoch 106 Loss: 0.0284, Accuracy: 0.9904
# === Epoch 107 ===
# Batch 0, Loss: 0.0278
# Batch 100, Loss: 0.0049
# Batch 200, Loss: 0.0094
# Batch 300, Loss: 0.0050
# Batch 400, Loss: 0.0020
# Batch 500, Loss: 0.0030
# Batch 600, Loss: 0.0002
# Batch 700, Loss: 0.0039
# Epoch 107 Loss: 0.0129, Accuracy: 0.9961
# === Epoch 108 ===
# Batch 0, Loss: 0.0008
# Batch 100, Loss: 0.0009
# Batch 200, Loss: 0.0005
# Batch 300, Loss: 0.0001
# Batch 400, Loss: 0.0054
# Batch 500, Loss: 0.0001
# Batch 600, Loss: 0.0001
# Batch 700, Loss: 0.0004
# Epoch 108 Loss: 0.0028, Accuracy: 0.9997
# === Epoch 109 ===
# Batch 0, Loss: 0.0004
# Batch 100, Loss: 0.0007
# Batch 200, Loss: 0.0004
# Batch 300, Loss: 0.0007
# Batch 400, Loss: 0.0030
# Batch 500, Loss: 0.0025
# Batch 600, Loss: 0.0049
# Batch 700, Loss: 0.0134
# Epoch 109 Loss: 0.0038, Accuracy: 0.9992
# === Epoch 110 ===
# Batch 0, Loss: 0.0029
# Batch 100, Loss: 0.0007
# Batch 200, Loss: 0.0023
# Batch 300, Loss: 0.0001
# Batch 400, Loss: 0.0050
# Batch 500, Loss: 0.0009
# Batch 600, Loss: 0.0013
# Batch 700, Loss: 0.0043
# Epoch 110 Loss: 0.0044, Accuracy: 0.9990
# === Epoch 111 ===
# Batch 0, Loss: 0.0013
# Batch 100, Loss: 0.0014
# Batch 200, Loss: 0.0041
# Batch 300, Loss: 0.0027
# Batch 400, Loss: 0.0053
# Batch 500, Loss: 0.0026
# Batch 600, Loss: 0.0013
# Batch 700, Loss: 0.0024
# Epoch 111 Loss: 0.0059, Accuracy: 0.9984
# === Epoch 112 ===
# Batch 0, Loss: 0.0021
# Batch 100, Loss: 0.0001
# Batch 200, Loss: 0.0010
# Batch 300, Loss: 0.0044
# Batch 400, Loss: 0.0262
# Batch 500, Loss: 0.0002
# Batch 600, Loss: 0.0005
# Batch 700, Loss: 0.0004
# Epoch 112 Loss: 0.0064, Accuracy: 0.9984
# === Epoch 113 ===
# Batch 0, Loss: 0.0011
# Batch 100, Loss: 0.0005
# Batch 200, Loss: 0.0005
# Batch 300, Loss: 0.0002
# Batch 400, Loss: 0.0009
# Batch 500, Loss: 0.0003
# Batch 600, Loss: 0.0010
# Batch 700, Loss: 0.0007
# Epoch 113 Loss: 0.0031, Accuracy: 0.9994
# === Epoch 114 ===
# Batch 0, Loss: 0.0012
# Batch 100, Loss: 0.0008
# Batch 200, Loss: 0.0005
# Batch 300, Loss: 0.0012
# Batch 400, Loss: 0.0002
# Batch 500, Loss: 0.0266
# Batch 600, Loss: 0.0004
# Batch 700, Loss: 0.0016
# Epoch 114 Loss: 0.0068, Accuracy: 0.9979
# === Epoch 115 ===
# Batch 0, Loss: 0.0017
# Batch 100, Loss: 0.0064
# Batch 200, Loss: 0.0032
# Batch 300, Loss: 0.0011
# Batch 400, Loss: 0.0025
# Batch 500, Loss: 0.0019
# Batch 600, Loss: 0.0009
# Batch 700, Loss: 0.0032
# Epoch 115 Loss: 0.0110, Accuracy: 0.9968
# === Epoch 116 ===
# Batch 0, Loss: 0.0164
# Batch 100, Loss: 0.0055
# Batch 200, Loss: 0.0018
# Batch 300, Loss: 0.0006
# Batch 400, Loss: 0.0015
# Batch 500, Loss: 0.0010
# Batch 600, Loss: 0.0015
# Batch 700, Loss: 0.0063
# Epoch 116 Loss: 0.0166, Accuracy: 0.9948
# === Epoch 117 ===
# Batch 0, Loss: 0.0029
# Batch 100, Loss: 0.0223
# Batch 200, Loss: 0.0005
# Batch 300, Loss: 0.0086
# Batch 400, Loss: 0.0306
# Batch 500, Loss: 0.0002
# Batch 600, Loss: 0.0031
# Batch 700, Loss: 0.0446
# Epoch 117 Loss: 0.0133, Accuracy: 0.9960
# === Epoch 118 ===
# Batch 0, Loss: 0.0488
# Batch 100, Loss: 0.0138
# Batch 200, Loss: 0.0049
# Batch 300, Loss: 0.0008
# Batch 400, Loss: 0.0100
# Batch 500, Loss: 0.0003
# Batch 600, Loss: 0.0017
# Batch 700, Loss: 0.0002
# Epoch 118 Loss: 0.0037, Accuracy: 0.9992
# === Epoch 119 ===
# Batch 0, Loss: 0.0012
# Batch 100, Loss: 0.0003
# Batch 200, Loss: 0.0051
# Batch 300, Loss: 0.0008
# Batch 400, Loss: 0.0009
# Batch 500, Loss: 0.0001
# Batch 600, Loss: 0.0001
# Batch 700, Loss: 0.0007
# Epoch 119 Loss: 0.0017, Accuracy: 0.9999
# === Epoch 120 ===
# Batch 0, Loss: 0.0002
# Batch 100, Loss: 0.0017
# Batch 200, Loss: 0.0006
# Batch 300, Loss: 0.0047
# Batch 400, Loss: 0.0001
# Batch 500, Loss: 0.0029
# Batch 600, Loss: 0.0014
# Batch 700, Loss: 0.0003
# Epoch 120 Loss: 0.0058, Accuracy: 0.9983
# === Epoch 121 ===
# Batch 0, Loss: 0.0116
# Batch 100, Loss: 0.0104
# Batch 200, Loss: 0.0301
# Batch 300, Loss: 0.0036
# Batch 400, Loss: 0.1792
# Batch 500, Loss: 0.0047
# Batch 600, Loss: 0.0053
# Batch 700, Loss: 0.0005
# Epoch 121 Loss: 0.0292, Accuracy: 0.9894
# === Epoch 122 ===
# Batch 0, Loss: 0.0066
# Batch 100, Loss: 0.0020
# Batch 200, Loss: 0.0051
# Batch 300, Loss: 0.0028
# Batch 400, Loss: 0.0056
# Batch 500, Loss: 0.0481
# Batch 600, Loss: 0.0108
# Batch 700, Loss: 0.0001
# Epoch 122 Loss: 0.0140, Accuracy: 0.9953
# === Epoch 123 ===
# Batch 0, Loss: 0.0006
# Batch 100, Loss: 0.0049
# Batch 200, Loss: 0.0017
# Batch 300, Loss: 0.0045
# Batch 400, Loss: 0.0002
# Batch 500, Loss: 0.0000
# Batch 600, Loss: 0.0009
# Batch 700, Loss: 0.0005
# Epoch 123 Loss: 0.0036, Accuracy: 0.9994
# === Epoch 124 ===
# Batch 0, Loss: 0.0020
# Batch 100, Loss: 0.0008
# Batch 200, Loss: 0.0014
# Batch 300, Loss: 0.0013
# Batch 400, Loss: 0.0005
# Batch 500, Loss: 0.0006
# Batch 600, Loss: 0.0000
# Batch 700, Loss: 0.0027
# Epoch 124 Loss: 0.0036, Accuracy: 0.9993
# === Epoch 125 ===
# Batch 0, Loss: 0.0003
# Batch 100, Loss: 0.0301
# Batch 200, Loss: 0.0703
# Batch 300, Loss: 0.0011
# Batch 400, Loss: 0.0443
# Batch 500, Loss: 0.0087
# Batch 600, Loss: 0.0007
# Batch 700, Loss: 0.0003
# Epoch 125 Loss: 0.0049, Accuracy: 0.9988
# === Epoch 126 ===
# Batch 0, Loss: 0.0015
# Batch 100, Loss: 0.0009
# Batch 200, Loss: 0.0011
# Batch 300, Loss: 0.0034
# Batch 400, Loss: 0.0003
# Batch 500, Loss: 0.0217
# Batch 600, Loss: 0.0046
# Batch 700, Loss: 0.0086
# Epoch 126 Loss: 0.0097, Accuracy: 0.9969
# === Epoch 127 ===
# Batch 0, Loss: 0.0036
# Batch 100, Loss: 0.0048
# Batch 200, Loss: 0.0040
# Batch 300, Loss: 0.0011
# Batch 400, Loss: 0.0006
# Batch 500, Loss: 0.0192
# Batch 600, Loss: 0.0048
# Batch 700, Loss: 0.0014
# Epoch 127 Loss: 0.0082, Accuracy: 0.9977
# === Epoch 128 ===
# Batch 0, Loss: 0.0005
# Batch 100, Loss: 0.0432
# Batch 200, Loss: 0.0002
# Batch 300, Loss: 0.0010
# Batch 400, Loss: 0.0054
# Batch 500, Loss: 0.0010
# Batch 600, Loss: 0.0070
# Batch 700, Loss: 0.0020
# Epoch 128 Loss: 0.0028, Accuracy: 0.9994
# === Epoch 129 ===
# Batch 0, Loss: 0.0008
# Batch 100, Loss: 0.0002
# Batch 200, Loss: 0.0010
# Batch 300, Loss: 0.0020
# Batch 400, Loss: 0.0021
# Batch 500, Loss: 0.0008
# Batch 600, Loss: 0.0000
# Batch 700, Loss: 0.0006
# Epoch 129 Loss: 0.0018, Accuracy: 0.9997
# === Epoch 130 ===
# Batch 0, Loss: 0.0040
# Batch 100, Loss: 0.0003
# Batch 200, Loss: 0.0133
# Batch 300, Loss: 0.0022
# Batch 400, Loss: 0.0002
# Batch 500, Loss: 0.0004
# Batch 600, Loss: 0.0010
# Batch 700, Loss: 0.0008
# Epoch 130 Loss: 0.0018, Accuracy: 0.9998
# === Epoch 131 ===
# Batch 0, Loss: 0.0006
# Batch 100, Loss: 0.0008
# Batch 200, Loss: 0.0003
# Batch 300, Loss: 0.0030
# Batch 400, Loss: 0.0015
# Batch 500, Loss: 0.0161
# Batch 600, Loss: 0.0018
# Batch 700, Loss: 0.0448
# Epoch 131 Loss: 0.0020, Accuracy: 0.9997
# === Epoch 132 ===
# Batch 0, Loss: 0.0026
# Batch 100, Loss: 0.0001
# Batch 200, Loss: 0.0012
# Batch 300, Loss: 0.0012
# Batch 400, Loss: 0.0157
# Batch 500, Loss: 0.0013
# Batch 600, Loss: 0.0003
# Batch 700, Loss: 0.0001
# Epoch 132 Loss: 0.0028, Accuracy: 0.9995
# === Epoch 133 ===
# Batch 0, Loss: 0.0005
# Batch 100, Loss: 0.0006
# Batch 200, Loss: 0.0007
# Batch 300, Loss: 0.0010
# Batch 400, Loss: 0.0027
# Batch 500, Loss: 0.0344
# Batch 600, Loss: 0.0002
# Batch 700, Loss: 0.0007
# Epoch 133 Loss: 0.0015, Accuracy: 0.9998
# === Epoch 134 ===
# Batch 0, Loss: 0.0001
# Batch 100, Loss: 0.0002
# Batch 200, Loss: 0.0012
# Batch 300, Loss: 0.0003
# Batch 400, Loss: 0.0003
# Batch 500, Loss: 0.0001
# Batch 600, Loss: 0.0029
# Batch 700, Loss: 0.0002
# Epoch 134 Loss: 0.0013, Accuracy: 0.9998
# === Epoch 135 ===
# Batch 0, Loss: 0.0007
# Batch 100, Loss: 0.0011
# Batch 200, Loss: 0.0019
# Batch 300, Loss: 0.0001
# Batch 400, Loss: 0.0003
# Batch 500, Loss: 0.0002
# Batch 600, Loss: 0.0001
# Batch 700, Loss: 0.0002
# Epoch 135 Loss: 0.0009, Accuracy: 1.0000
# === Epoch 136 ===
# Batch 0, Loss: 0.0022
# Batch 100, Loss: 0.0003
# Batch 200, Loss: 0.0003
# Batch 300, Loss: 0.0004
# Batch 400, Loss: 0.0009
# Batch 500, Loss: 0.0007
# Batch 600, Loss: 0.0658
# Batch 700, Loss: 0.0148
# Epoch 136 Loss: 0.0141, Accuracy: 0.9956
# === Epoch 137 ===
# Batch 0, Loss: 0.1453
# Batch 100, Loss: 0.0314
# Batch 200, Loss: 0.0080
# Batch 300, Loss: 0.0031
# Batch 400, Loss: 0.0058
# Batch 500, Loss: 0.0007
# Batch 600, Loss: 0.0194
# Batch 700, Loss: 0.0040
# Epoch 137 Loss: 0.0235, Accuracy: 0.9928
# === Epoch 138 ===
# Batch 0, Loss: 0.0586
# Batch 100, Loss: 0.0019
# Batch 200, Loss: 0.0016
# Batch 300, Loss: 0.0015
# Batch 400, Loss: 0.0006
# Batch 500, Loss: 0.0010
# Batch 600, Loss: 0.0018
# Batch 700, Loss: 0.0002
# Epoch 138 Loss: 0.0064, Accuracy: 0.9985
# === Epoch 139 ===
# Batch 0, Loss: 0.0003
# Batch 100, Loss: 0.0002
# Batch 200, Loss: 0.0042
# Batch 300, Loss: 0.0004
# Batch 400, Loss: 0.0009
# Batch 500, Loss: 0.0006
# Batch 600, Loss: 0.0002
# Batch 700, Loss: 0.0012
# Epoch 139 Loss: 0.0022, Accuracy: 0.9998
# === Epoch 140 ===
# Batch 0, Loss: 0.0003
# Batch 100, Loss: 0.0002
# Batch 200, Loss: 0.0007
# Batch 300, Loss: 0.0001
# Batch 400, Loss: 0.0012
# Batch 500, Loss: 0.0003
# Batch 600, Loss: 0.0001
# Batch 700, Loss: 0.0003
# Epoch 140 Loss: 0.0018, Accuracy: 0.9996
# === Epoch 141 ===
# Batch 0, Loss: 0.0009
# Batch 100, Loss: 0.0015
# Batch 200, Loss: 0.0007
# Batch 300, Loss: 0.0268
# Batch 400, Loss: 0.0001
# Batch 500, Loss: 0.0017
# Batch 600, Loss: 0.0027
# Batch 700, Loss: 0.0010
# Epoch 141 Loss: 0.0040, Accuracy: 0.9989
# === Epoch 142 ===
# Batch 0, Loss: 0.0066
# Batch 100, Loss: 0.0019
# Batch 200, Loss: 0.0051
# Batch 300, Loss: 0.0005
# Batch 400, Loss: 0.0000
# Batch 500, Loss: 0.0006
# Batch 600, Loss: 0.0138
# Batch 700, Loss: 0.0007
# Epoch 142 Loss: 0.0021, Accuracy: 0.9997
# === Epoch 143 ===
# Batch 0, Loss: 0.0006
# Batch 100, Loss: 0.0001
# Batch 200, Loss: 0.0001
# Batch 300, Loss: 0.0035
# Batch 400, Loss: 0.0020
# Batch 500, Loss: 0.0020
# Batch 600, Loss: 0.0002
# Batch 700, Loss: 0.0005
# Epoch 143 Loss: 0.0022, Accuracy: 0.9995
# === Epoch 144 ===
# Batch 0, Loss: 0.0002
# Batch 100, Loss: 0.0002
# Batch 200, Loss: 0.0098
# Batch 300, Loss: 0.0005
# Batch 400, Loss: 0.0019
# Batch 500, Loss: 0.0000
# Batch 600, Loss: 0.0001
# Batch 700, Loss: 0.0001
# Epoch 144 Loss: 0.0012, Accuracy: 0.9998
# === Epoch 145 ===
# Batch 0, Loss: 0.0011
# Batch 100, Loss: 0.0009
# Batch 200, Loss: 0.0008
# Batch 300, Loss: 0.0009
# Batch 400, Loss: 0.0580
# Batch 500, Loss: 0.0197
# Batch 600, Loss: 0.0009
# Batch 700, Loss: 0.0014
# Epoch 145 Loss: 0.0077, Accuracy: 0.9974
# === Epoch 146 ===
# Batch 0, Loss: 0.0220
# Batch 100, Loss: 0.0002
# Batch 200, Loss: 0.0003
# Batch 300, Loss: 0.0018
# Batch 400, Loss: 0.0018
# Batch 500, Loss: 0.0050
# Batch 600, Loss: 0.0017
# Batch 700, Loss: 0.0004
# Epoch 146 Loss: 0.0162, Accuracy: 0.9951
# === Epoch 147 ===
# Batch 0, Loss: 0.0049
# Batch 100, Loss: 0.0192
# Batch 200, Loss: 0.0206
# Batch 300, Loss: 0.0043
# Batch 400, Loss: 0.0098
# Batch 500, Loss: 0.0051
# Batch 600, Loss: 0.2101
# Batch 700, Loss: 0.0020
# Epoch 147 Loss: 0.0201, Accuracy: 0.9934
# === Epoch 148 ===
# Batch 0, Loss: 0.0024
# Batch 100, Loss: 0.0210
# Batch 200, Loss: 0.0153
# Batch 300, Loss: 0.0008
# Batch 400, Loss: 0.0021
# Batch 500, Loss: 0.0016
# Batch 600, Loss: 0.0009
# Batch 700, Loss: 0.0077
# Epoch 148 Loss: 0.0077, Accuracy: 0.9980
# === Epoch 149 ===
# Batch 0, Loss: 0.0009
# Batch 100, Loss: 0.0099
# Batch 200, Loss: 0.0001
# Batch 300, Loss: 0.0017
# Batch 400, Loss: 0.0023
# Batch 500, Loss: 0.0084
# Batch 600, Loss: 0.0011
# Batch 700, Loss: 0.0004
# Epoch 149 Loss: 0.0027, Accuracy: 0.9995
# === Epoch 150 ===
# Batch 0, Loss: 0.0006
# Batch 100, Loss: 0.0004
# Batch 200, Loss: 0.0091
# Batch 300, Loss: 0.0031
# Batch 400, Loss: 0.0013
# Batch 500, Loss: 0.0004
# Batch 600, Loss: 0.0007
# Batch 700, Loss: 0.0027
# Epoch 150 Loss: 0.0050, Accuracy: 0.9985
# === Epoch 151 ===
# Batch 0, Loss: 0.0083
# Batch 100, Loss: 0.0004
# Batch 200, Loss: 0.0002
# Batch 300, Loss: 0.0006
# Batch 400, Loss: 0.0037
# Batch 500, Loss: 0.0016
# Batch 600, Loss: 0.0031
# Batch 700, Loss: 0.0341
# Epoch 151 Loss: 0.0152, Accuracy: 0.9952
# === Epoch 152 ===
# Batch 0, Loss: 0.0100
# Batch 100, Loss: 0.0822
# Batch 200, Loss: 0.0021
# Batch 300, Loss: 0.0926
# Batch 400, Loss: 0.0185
# Batch 500, Loss: 0.0017
# Batch 600, Loss: 0.0033
# Batch 700, Loss: 0.0060
# Epoch 152 Loss: 0.0251, Accuracy: 0.9912
# === Epoch 153 ===
# Batch 0, Loss: 0.0013
# Batch 100, Loss: 0.0004
# Batch 200, Loss: 0.0004
# Batch 300, Loss: 0.0021
# Batch 400, Loss: 0.0002
# Batch 500, Loss: 0.0009
# Batch 600, Loss: 0.0005
# Batch 700, Loss: 0.0013
# Epoch 153 Loss: 0.0046, Accuracy: 0.9989
# === Epoch 154 ===
# Batch 0, Loss: 0.0008
# Batch 100, Loss: 0.0003
# Batch 200, Loss: 0.0002
# Batch 300, Loss: 0.0005
# Batch 400, Loss: 0.0089
# Batch 500, Loss: 0.0006
# Batch 600, Loss: 0.0002
# Batch 700, Loss: 0.0009
# Epoch 154 Loss: 0.0022, Accuracy: 0.9996
# === Epoch 155 ===
# Batch 0, Loss: 0.0001
# Batch 100, Loss: 0.0001
# Batch 200, Loss: 0.0022
# Batch 300, Loss: 0.0001
# Batch 400, Loss: 0.0008
# Batch 500, Loss: 0.0002
# Batch 600, Loss: 0.0006
# Batch 700, Loss: 0.0008
# Epoch 155 Loss: 0.0020, Accuracy: 0.9997
# === Epoch 156 ===
# Batch 0, Loss: 0.0003
# Batch 100, Loss: 0.0004
# Batch 200, Loss: 0.0002
# Batch 300, Loss: 0.0010
# Batch 400, Loss: 0.0007
# Batch 500, Loss: 0.0002
# Batch 600, Loss: 0.0004
# Batch 700, Loss: 0.0066
# Epoch 156 Loss: 0.0030, Accuracy: 0.9992
# === Epoch 157 ===
# Batch 0, Loss: 0.0018
# Batch 100, Loss: 0.0003
# Batch 200, Loss: 0.0031
# Batch 300, Loss: 0.0007
# Batch 400, Loss: 0.0171
# Batch 500, Loss: 0.0028
# Batch 600, Loss: 0.0030
# Batch 700, Loss: 0.0003
# Epoch 157 Loss: 0.0060, Accuracy: 0.9983
# === Epoch 158 ===
# Batch 0, Loss: 0.0057
# Batch 100, Loss: 0.0017
# Batch 200, Loss: 0.0020
# Batch 300, Loss: 0.0002
# Batch 400, Loss: 0.0033
# Batch 500, Loss: 0.0001
# Batch 600, Loss: 0.0004
# Batch 700, Loss: 0.0014
# Epoch 158 Loss: 0.0037, Accuracy: 0.9992
# === Epoch 159 ===
# Batch 0, Loss: 0.0001
# Batch 100, Loss: 0.0001
# Batch 200, Loss: 0.0008
# Batch 300, Loss: 0.0002
# Batch 400, Loss: 0.0026
# Batch 500, Loss: 0.0001
# Batch 600, Loss: 0.0001
# Batch 700, Loss: 0.0004
# Epoch 159 Loss: 0.0014, Accuracy: 0.9999
# === Epoch 160 ===
# Batch 0, Loss: 0.0003
# Batch 100, Loss: 0.0002
# Batch 200, Loss: 0.0001
# Batch 300, Loss: 0.0001
# Batch 400, Loss: 0.0001
# Batch 500, Loss: 0.0001
# Batch 600, Loss: 0.0039
# Batch 700, Loss: 0.0037
# Epoch 160 Loss: 0.0025, Accuracy: 0.9994
# === Epoch 161 ===
# Batch 0, Loss: 0.0002
# Batch 100, Loss: 0.0008
# Batch 200, Loss: 0.0005
# Batch 300, Loss: 0.0051
# Batch 400, Loss: 0.0001
# Batch 500, Loss: 0.0024
# Batch 600, Loss: 0.0022
# Batch 700, Loss: 0.0002
# Epoch 161 Loss: 0.0027, Accuracy: 0.9993
# === Epoch 162 ===
# Batch 0, Loss: 0.0184
# Batch 100, Loss: 0.0158
# Batch 200, Loss: 0.0110
# Batch 300, Loss: 0.0018
# Batch 400, Loss: 0.0132
# Batch 500, Loss: 0.0333
# Batch 600, Loss: 0.0095
# Batch 700, Loss: 0.0055
# Epoch 162 Loss: 0.0403, Accuracy: 0.9875
# === Epoch 163 ===
# Batch 0, Loss: 0.0125
# Batch 100, Loss: 0.0050
# Batch 200, Loss: 0.0028
# Batch 300, Loss: 0.0146
# Batch 400, Loss: 0.0080
# Batch 500, Loss: 0.0007
# Batch 600, Loss: 0.0011
# Batch 700, Loss: 0.0005
# Epoch 163 Loss: 0.0134, Accuracy: 0.9960
# === Epoch 164 ===
# Batch 0, Loss: 0.0012
# Batch 100, Loss: 0.0010
# Batch 200, Loss: 0.0001
# Batch 300, Loss: 0.0009
# Batch 400, Loss: 0.0022
# Batch 500, Loss: 0.0009
# Batch 600, Loss: 0.0003
# Batch 700, Loss: 0.0002
# Epoch 164 Loss: 0.0031, Accuracy: 0.9994
# === Epoch 165 ===
# Batch 0, Loss: 0.0005
# Batch 100, Loss: 0.0003
# Batch 200, Loss: 0.0004
# Batch 300, Loss: 0.0008
# Batch 400, Loss: 0.0001
# Batch 500, Loss: 0.0007
# Batch 600, Loss: 0.0003
# Batch 700, Loss: 0.0054
# Epoch 165 Loss: 0.0031, Accuracy: 0.9993
# === Epoch 166 ===
# Batch 0, Loss: 0.0003
# Batch 100, Loss: 0.0004
# Batch 200, Loss: 0.0010
# Batch 300, Loss: 0.0005
# Batch 400, Loss: 0.0006
# Batch 500, Loss: 0.0011
# Batch 600, Loss: 0.0063
# Batch 700, Loss: 0.0004
# Epoch 166 Loss: 0.0064, Accuracy: 0.9983
# === Epoch 167 ===
# Batch 0, Loss: 0.0282
# Batch 100, Loss: 0.0984
# Batch 200, Loss: 0.0059
# Batch 300, Loss: 0.0051
# Batch 400, Loss: 0.0033
# Batch 500, Loss: 0.0029
# Batch 600, Loss: 0.0637
# Batch 700, Loss: 0.0133
# Epoch 167 Loss: 0.0407, Accuracy: 0.9866
# === Epoch 168 ===
# Batch 0, Loss: 0.0012
# Batch 100, Loss: 0.0123
# Batch 200, Loss: 0.0148
# Batch 300, Loss: 0.0013
# Batch 400, Loss: 0.0005
# Batch 500, Loss: 0.0021
# Batch 600, Loss: 0.0045
# Batch 700, Loss: 0.0040
# Epoch 168 Loss: 0.0087, Accuracy: 0.9976
# === Epoch 169 ===
# Batch 0, Loss: 0.0049
# Batch 100, Loss: 0.0033
# Batch 200, Loss: 0.0008
# Batch 300, Loss: 0.0040
# Batch 400, Loss: 0.0008
# Batch 500, Loss: 0.0002
# Batch 600, Loss: 0.0002
# Batch 700, Loss: 0.0015
# Epoch 169 Loss: 0.0068, Accuracy: 0.9984
# === Epoch 170 ===
# Batch 0, Loss: 0.0017
# Batch 100, Loss: 0.0008
# Batch 200, Loss: 0.0003
# Batch 300, Loss: 0.0058
# Batch 400, Loss: 0.0002
# Batch 500, Loss: 0.0038
# Batch 600, Loss: 0.0003
# Batch 700, Loss: 0.0004
# Epoch 170 Loss: 0.0036, Accuracy: 0.9993
# === Epoch 171 ===
# Batch 0, Loss: 0.0058
# Batch 100, Loss: 0.0001
# Batch 200, Loss: 0.0135
# Batch 300, Loss: 0.0031
# Batch 400, Loss: 0.0033
# Batch 500, Loss: 0.0004
# Batch 600, Loss: 0.0015
# Batch 700, Loss: 0.0051
# Epoch 171 Loss: 0.0029, Accuracy: 0.9994
# === Epoch 172 ===
# Batch 0, Loss: 0.0006
# Batch 100, Loss: 0.0004
# Batch 200, Loss: 0.0031
# Batch 300, Loss: 0.0021
# Batch 400, Loss: 0.0170
# Batch 500, Loss: 0.0077
# Batch 600, Loss: 0.0260
# Batch 700, Loss: 0.0120
# Epoch 172 Loss: 0.0103, Accuracy: 0.9967
# === Epoch 173 ===
# Batch 0, Loss: 0.0089
# Batch 100, Loss: 0.0002
# Batch 200, Loss: 0.0002
# Batch 300, Loss: 0.0024
# Batch 400, Loss: 0.0001
# Batch 500, Loss: 0.0003
# Batch 600, Loss: 0.0013
# Batch 700, Loss: 0.0010
# Epoch 173 Loss: 0.0052, Accuracy: 0.9986
# === Epoch 174 ===
# Batch 0, Loss: 0.0008
# Batch 100, Loss: 0.0009
# Batch 200, Loss: 0.0054
# Batch 300, Loss: 0.0005
# Batch 400, Loss: 0.0000
# Batch 500, Loss: 0.0002
# Batch 600, Loss: 0.0003
# Batch 700, Loss: 0.0260
# Epoch 174 Loss: 0.0020, Accuracy: 0.9996
# === Epoch 175 ===
# Batch 0, Loss: 0.0010
# Batch 100, Loss: 0.0013
# Batch 200, Loss: 0.0002
# Batch 300, Loss: 0.0001
# Batch 400, Loss: 0.0003
# Batch 500, Loss: 0.0019
# Batch 600, Loss: 0.0010
# Batch 700, Loss: 0.0014
# Epoch 175 Loss: 0.0016, Accuracy: 0.9998
# === Epoch 176 ===
# Batch 0, Loss: 0.0005
# Batch 100, Loss: 0.0012
# Batch 200, Loss: 0.0002
# Batch 300, Loss: 0.0005
# Batch 400, Loss: 0.0001
# Batch 500, Loss: 0.0013
# Batch 600, Loss: 0.0004
# Batch 700, Loss: 0.0003
# Epoch 176 Loss: 0.0039, Accuracy: 0.9992
# === Epoch 177 ===
# Batch 0, Loss: 0.0015
# Batch 100, Loss: 0.0062
# Batch 200, Loss: 0.0069
# Batch 300, Loss: 0.0048
# Batch 400, Loss: 0.0168
# Batch 500, Loss: 0.0076
# Batch 600, Loss: 0.0108
# Batch 700, Loss: 0.0196
# Epoch 177 Loss: 0.0219, Accuracy: 0.9921
# === Epoch 178 ===
# Batch 0, Loss: 0.0217
# Batch 100, Loss: 0.0040
# Batch 200, Loss: 0.0129
# Batch 300, Loss: 0.0020
# Batch 400, Loss: 0.0115
# Batch 500, Loss: 0.0032
# Batch 600, Loss: 0.0022
# Batch 700, Loss: 0.0032
# Epoch 178 Loss: 0.0137, Accuracy: 0.9955
# === Epoch 179 ===
# Batch 0, Loss: 0.0003
# Batch 100, Loss: 0.0032
# Batch 200, Loss: 0.0022
# Batch 300, Loss: 0.0014
# Batch 400, Loss: 0.0006
# Batch 500, Loss: 0.0019
# Batch 600, Loss: 0.0001
# Batch 700, Loss: 0.0004
# Epoch 179 Loss: 0.0038, Accuracy: 0.9991
# === Epoch 180 ===
# Batch 0, Loss: 0.0042
# Batch 100, Loss: 0.0010
# Batch 200, Loss: 0.0008
# Batch 300, Loss: 0.0003
# Batch 400, Loss: 0.0033
# Batch 500, Loss: 0.0001
# Batch 600, Loss: 0.0001
# Batch 700, Loss: 0.0003
# Epoch 180 Loss: 0.0019, Accuracy: 0.9997
# === Epoch 181 ===
# Batch 0, Loss: 0.0005
# Batch 100, Loss: 0.0007
# Batch 200, Loss: 0.0001
# Batch 300, Loss: 0.0034
# Batch 400, Loss: 0.0069
# Batch 500, Loss: 0.0048
# Batch 600, Loss: 0.0025
# Batch 700, Loss: 0.0004
# Epoch 181 Loss: 0.0030, Accuracy: 0.9993
# === Epoch 182 ===
# Batch 0, Loss: 0.0008
# Batch 100, Loss: 0.0020
# Batch 200, Loss: 0.0018
# Batch 300, Loss: 0.0002
# Batch 400, Loss: 0.0000
# Batch 500, Loss: 0.0003
# Batch 600, Loss: 0.0007
# Batch 700, Loss: 0.0009
# Epoch 182 Loss: 0.0021, Accuracy: 0.9997
# === Epoch 183 ===
# Batch 0, Loss: 0.0006
# Batch 100, Loss: 0.0013
# Batch 200, Loss: 0.0011
# Batch 300, Loss: 0.0001
# Batch 400, Loss: 0.0120
# Batch 500, Loss: 0.0001
# Batch 600, Loss: 0.0030
# Batch 700, Loss: 0.0001
# Epoch 183 Loss: 0.0027, Accuracy: 0.9994
# === Epoch 184 ===
# Batch 0, Loss: 0.0014
# Batch 100, Loss: 0.0003
# Batch 200, Loss: 0.0003
# Batch 300, Loss: 0.0061
# Batch 400, Loss: 0.0008
# Batch 500, Loss: 0.0025
# Batch 600, Loss: 0.0014
# Batch 700, Loss: 0.0001
# Epoch 184 Loss: 0.0013, Accuracy: 0.9998
# === Epoch 185 ===
# Batch 0, Loss: 0.0001
# Batch 100, Loss: 0.0001
# Batch 200, Loss: 0.0029
# Batch 300, Loss: 0.0003
# Batch 400, Loss: 0.0001
# Batch 500, Loss: 0.0001
# Batch 600, Loss: 0.0001
# Batch 700, Loss: 0.0007
# Epoch 185 Loss: 0.0009, Accuracy: 0.9999
# === Epoch 186 ===
# Batch 0, Loss: 0.0001
# Batch 100, Loss: 0.0001
# Batch 200, Loss: 0.0001
# Batch 300, Loss: 0.0244
# Batch 400, Loss: 0.0002
# Batch 500, Loss: 0.0002
# Batch 600, Loss: 0.0005
# Batch 700, Loss: 0.0002
# Epoch 186 Loss: 0.0014, Accuracy: 0.9997
# Finished training

# %% [markdown]
# Test

# %%
df_test = pd.read_csv(test_file)

test_data = []
image_ids = []
for idx, row in df_test.iterrows():
    img_name = row['image_id'] + '.png'
    img_path = os.path.join(test_dir, img_name)
    image = cv2.imread(img_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    image_resized = cv2.resize(image_rgb, (100, 100))
    
    normalized_image = cv2.normalize(image_resized.astype('float32'), None, 0, 1, cv2.NORM_MINMAX)
    image_tensor = torch.from_numpy(normalized_image).permute(2, 0, 1).float()
    test_data.append(image_tensor)
    image_ids.append(row['image_id'])

test_images = torch.stack(test_data)
test_dataset = TensorDataset(test_images) 
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=8)

model.to(device)
model.eval()
predicted_labels = []
with torch.no_grad():
    for image_batch in test_loader:
        images = image_batch[0].to(device)
        outputs = model(images)
        preds = outputs.argmax(dim=1).cpu()
        predicted_labels.extend(preds.tolist())

print(predicted_labels)
predictions_df = pd.DataFrame({'image_id': image_ids, 'label': predicted_labels})
predictions_df.to_csv('deepfake-classification/cnn_prediction.csv', index=False)
print("Predictions saved to prediction.csv")
# Out:
# [4, 3, 0, 2, 1, 3, 0, 4, 3, 1, 3, 2, 3, 2, 2, 1, 0, 3, 3, 3, 4, 0, 0, 0, 1, 3, 1, 2, 4, 3, 3, 4, 0, 1, 2, 0, 4, 1, 3, 1, 0, 0, 0, 2, 0, 2, 1, 2, 4, 3, 4, 1, 3, 1, 3, 3, 2, 1, 2, 4, 1, 4, 2, 0, 4, 2, 1, 4, 2, 3, 3, 1, 0, 0, 1, 2, 3, 2, 2, 3, 1, 1, 2, 0, 3, 1, 4, 0, 2, 0, 0, 2, 3, 1, 1, 4, 0, 3, 2, 4, 3, 3, 3, 2, 2, 2, 3, 4, 2, 0, 4, 0, 3, 1, 2, 2, 1, 3, 4, 1, 0, 1, 0, 1, 0, 4, 3, 1, 2, 4, 1, 3, 1, 3, 0, 2, 0, 1, 1, 2, 3, 1, 4, 3, 3, 2, 3, 3, 0, 3, 2, 0, 1, 2, 2, 1, 3, 1, 0, 4, 3, 0, 2, 1, 0, 2, 2, 4, 2, 2, 3, 1, 4, 4, 0, 4, 4, 2, 1, 0, 1, 3, 2, 1, 2, 4, 0, 3, 3, 2, 2, 2, 3, 1, 4, 3, 2, 0, 0, 4, 2, 4, 2, 2, 4, 0, 3, 0, 3, 1, 0, 0, 0, 0, 2, 4, 1, 1, 1, 4, 0, 1, 3, 1, 0, 2, 4, 4, 1, 0, 2, 4, 3, 4, 4, 0, 3, 2, 2, 1, 0, 2, 0, 1, 0, 3, 4, 0, 3, 1, 4, 3, 3, 1, 3, 1, 3, 0, 2, 2, 1, 2, 4, 1, 4, 1, 0, 0, 4, 0, 4, 4, 1, 0, 4, 0, 3, 2, 2, 2, 4, 4, 3, 4, 0, 0, 3, 4, 0, 2, 4, 4, 1, 2, 3, 1, 1, 4, 3, 3, 3, 3, 1, 1, 0, 3, 1, 0, 4, 4, 3, 1, 3, 1, 3, 3, 0, 4, 1, 2, 0, 4, 0, 4, 0, 4, 2, 0, 0, 2, 0, 0, 1, 2, 0, 3, 1, 0, 0, 0, 1, 0, 1, 3, 2, 1, 0, 1, 4, 2, 3, 3, 2, 3, 2, 2, 0, 2, 4, 0, 2, 2, 3, 2, 2, 1, 0, 4, 2, 0, 1, 4, 0, 1, 1, 1, 1, 1, 3, 0, 4, 2, 1, 3, 0, 1, 0, 3, 4, 4, 0, 4, 3, 3, 2, 0, 2, 2, 1, 4, 0, 4, 0, 0, 3, 4, 2, 3, 4, 1, 4, 2, 0, 2, 1, 3, 3, 3, 3, 2, 3, 4, 3, 0, 0, 4, 0, 1, 0, 3, 1, 1, 4, 4, 2, 0, 3, 1, 0, 1, 2, 2, 2, 0, 2, 4, 1, 2, 2, 1, 3, 4, 3, 3, 2, 2, 0, 4, 0, 0, 1, 1, 1, 1, 3, 0, 2, 4, 4, 4, 2, 3, 2, 2, 4, 2, 4, 4, 0, 3, 2, 4, 4, 4, 0, 4, 0, 4, 0, 3, 3, 0, 2, 2, 1, 3, 3, 2, 4, 0, 4, 4, 1, 3, 1, 3, 4, 2, 1, 4, 0, 1, 1, 3, 0, 3, 1, 0, 2, 2, 1, 1, 3, 3, 2, 2, 0, 2, 3, 4, 3, 1, 3, 0, 4, 2, 2, 2, 0, 2, 0, 3, 4, 3, 0, 4, 0, 0, 0, 3, 2, 2, 3, 1, 2, 0, 1, 0, 3, 1, 2, 4, 4, 1, 2, 3, 3, 1, 0, 1, 0, 0, 1, 3, 2, 4, 4, 4, 4, 1, 0, 0, 4, 2, 2, 1, 1, 1, 4, 2, 3, 2, 1, 2, 0, 1, 1, 1, 1, 0, 2, 0, 0, 4, 1, 3, 3, 0, 1, 1, 0, 3, 2, 2, 2, 3, 1, 1, 1, 3, 0, 2, 2, 3, 3, 1, 1, 3, 1, 1, 2, 0, 2, 1, 2, 2, 0, 4, 4, 3, 1, 2, 4, 0, 3, 0, 2, 4, 4, 2, 1, 0, 3, 3, 3, 3, 3, 0, 0, 3, 4, 4, 4, 4, 0, 3, 4, 0, 3, 2, 3, 2, 0, 4, 4, 0, 3, 2, 2, 2, 4, 1, 2, 4, 4, 0, 4, 3, 4, 3, 4, 2, 0, 0, 2, 1, 2, 4, 4, 3, 3, 1, 1, 1, 0, 0, 2, 3, 1, 0, 2, 1, 2, 4, 4, 2, 4, 1, 2, 2, 3, 4, 3, 0, 0, 3, 0, 0, 3, 2, 1, 3, 0, 1, 1, 1, 1, 0, 3, 1, 1, 2, 1, 2, 3, 2, 1, 0, 1, 3, 1, 3, 4, 4, 2, 2, 1, 0, 1, 3, 1, 0, 1, 1, 3, 3, 2, 2, 1, 0, 2, 4, 3, 2, 0, 0, 2, 1, 3, 0, 2, 3, 2, 3, 2, 1, 0, 3, 2, 1, 2, 0, 3, 2, 3, 0, 3, 1, 2, 4, 0, 0, 0, 2, 1, 1, 2, 2, 2, 1, 2, 2, 3, 1, 4, 4, 2, 0, 0, 0, 2, 1, 4, 1, 2, 2, 0, 1, 1, 0, 3, 3, 4, 0, 0, 0, 3, 2, 0, 0, 4, 1, 2, 3, 3, 4, 2, 2, 0, 2, 2, 2, 1, 2, 3, 0, 1, 3, 0, 2, 1, 0, 4, 1, 0, 1, 3, 0, 3, 3, 1, 1, 3, 0, 2, 4, 4, 4, 3, 0, 4, 4, 4, 2, 4, 3, 2, 4, 2, 2, 4, 4, 3, 1, 4, 1, 1, 1, 0, 1, 4, 0, 2, 4, 0, 4, 3, 1, 0, 4, 4, 4, 3, 3, 3, 0, 2, 4, 0, 2, 4, 3, 3, 2, 0, 0, 4, 0, 1, 4, 0, 3, 3, 3, 0, 1, 2, 2, 1, 1, 4, 2, 3, 2, 3, 1, 0, 3, 4, 2, 0, 1, 1, 4, 0, 2, 2, 3, 3, 1, 2, 0, 1, 4, 1, 4, 4, 2, 4, 3, 4, 3, 3, 3, 2, 1, 3, 1, 1, 1, 3, 3, 4, 3, 4, 2, 2, 0, 1, 4, 1, 1, 1, 1, 3, 0, 3, 4, 4, 0, 1, 4, 4, 4, 0, 1, 4, 2, 3, 1, 4, 4, 1, 1, 4, 2, 0, 2, 3, 3, 2, 0, 2, 1, 0, 1, 1, 0, 4, 2, 2, 1, 3, 2, 3, 1, 4, 0, 3, 3, 3, 2, 1, 3, 2, 0, 4, 0, 4, 0, 0, 2, 4, 4, 1, 0, 1, 1, 2, 4, 2, 4, 2, 3, 3, 2, 1, 1, 3, 4, 4, 4, 4, 3, 1, 0, 4, 1, 0, 0, 2, 2, 3, 1, 0, 0, 1, 2, 4, 1, 0, 1, 0, 3, 2, 0, 3, 2, 3, 2, 2, 4, 0, 0, 0, 4, 0, 0, 2, 4, 0, 1, 2, 1, 4, 4, 3, 2, 0, 4, 2, 1, 3, 2, 3, 2, 0, 3, 3, 0, 4, 2, 2, 0, 3, 3, 0, 4, 3, 3, 3, 0, 4, 3, 0, 1, 4, 0, 4, 0, 3, 4, 0, 3, 1, 3, 1, 3, 4, 4, 4, 4, 1, 3, 1, 4, 4, 0, 2, 1, 2, 1, 3, 2, 3, 2, 0, 4, 4, 3, 3, 2, 2, 1, 1, 3, 4, 2, 0, 4, 2, 1, 4, 4, 1, 3, 1, 0, 0, 0, 0, 0, 3, 1, 2, 2, 1, 0, 4, 0, 4, 4, 1, 1, 1, 0, 3, 4, 4, 3, 1, 3, 4, 3, 0, 2, 2, 0, 3, 4, 2, 3, 4, 4, 2, 3, 0, 0, 1, 2, 4, 0, 3, 1, 0, 4, 2, 2, 0, 1, 1, 4, 4, 2, 2, 4, 0, 0, 1, 3, 2, 3, 1, 2, 3, 2, 0, 4, 2, 1, 2, 4, 2, 3, 2, 2, 4, 1, 2, 3, 4, 0, 0, 0, 4, 3, 0, 3, 2, 4, 3, 1, 3, 4, 4, 4, 1, 1, 3, 3, 4, 3, 3, 2, 0, 3, 4, 2, 2, 2, 0, 3, 4, 0, 0, 0, 2, 1, 4, 1, 1, 1, 2, 4, 2, 0, 1, 3, 3, 1, 4, 0, 1,  ...
# Predictions saved to prediction.csv

# %% [markdown]
# Validation

# %%
df_val = pd.read_csv(validation_file)

val_data = []
validation_predictions = []
validation_correct_labels = []
for idx, row in df_val.iterrows():
    img_name = row['image_id'] + '.png'
    label = row['label']
    img_path = os.path.join(val_dir, img_name)
    image = cv2.imread(img_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    image_resized = cv2.resize(image_rgb, (100, 100))
    
    normalized_image = cv2.normalize(image_resized.astype('float32'), None, 0, 1, cv2.NORM_MINMAX)
    image_tensor = torch.from_numpy(normalized_image).permute(2, 0, 1).float()
    val_data.append((image_tensor, label))

val_images = torch.stack([item[0] for item in val_data])
val_labels = torch.tensor([item[1] for item in val_data])

val_dataset = TensorDataset(val_images, val_labels)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=8)

model.eval()
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in val_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        preds = outputs.argmax(dim=1)
        validation_predictions.extend(preds.cpu().numpy())
        validation_correct_labels.extend(labels.cpu().numpy())
        correct += (preds == labels).sum().item()
        total += labels.size(0)

accuracy = correct / total
print(f'Validation Accuracy: {accuracy*100:.2f}%')

conf_matrix = confusion_matrix(validation_correct_labels, validation_predictions)
print(f"Confusion Matrix:\n{conf_matrix}")

plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# 92.88%
# Out:
# Validation Accuracy: 90.32%
# Confusion Matrix:
# [[228   4   6   2  10]
#  [  0 228   2   2  18]
#  [  3   2 232   0  13]
#  [  0   1   1 248   0]
#  [ 16  31  10   0 193]]
